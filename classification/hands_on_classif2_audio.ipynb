# %%
### TO RUN
import os
import numpy as np
import matplotlib.pyplot as plt

"Machine learning tools"
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.decomposition import PCA
import pickle

from classification.datasets import Dataset
from classification.utils.plots import plot_specgram, show_confusion_matrix, plot_decision_boundaries
from classification.utils.utils import accuracy
from classification.utils.audio_student import AudioUtil, Feature_vector_DS

# %%
np.random.seed(0)

# %% [markdown]
# Useful functions to select, read and play the dataset sounds are provided in ``classification/utils/audio_student.py``. <br>
#
# As for the H1, you will have to fill some short pieces of code, as well as answer some questions. We already created cells for you to answer the questions to ensure you don't forget it ;). <br>
# You will find the zones to be briefly filled  with a ``### TO COMPLETE`` in the cells below.
#
# <font size=6 color=#009999> 2. Training and Evaluating models on audio signals [~1h30-2h] </font> <br>

# %%
### TO RUN
dataset = Dataset()
classnames = dataset.list_classes()

print("\n".join(classnames))
# Out:
# birds
# chainsaw
# fire
# handsaw
# helicopter

# %%
### TO RUN
fm_dir = "data/feature_matrices/" # where to save the features matrices
model_dir = "data/models/" # where to save the models
os.makedirs(fm_dir, exist_ok=True)
os.makedirs(model_dir, exist_ok=True)

# %% [markdown]
# In H1, it was not made explicit what we choose as input for the classification model, a.k.a. ``feature vector`` (it was shown in the illustration). <br>
# The objective is, on the transmitter side, to compute a feature vector containing enough information about the audio signal we want to classify, but not too much in order to limit the data which has to be transmitted wirelessly. This is why in H1 we implemented the ``Hz2Mel`` conversion: a very simple compression of the frequency content. <br>
# The feature vector we will use here simply consists in taking the first 20 columns of the melspectrogram, corresponding to ~1s, then reshaping it as a vector. This means each feature vector contains ``400`` coefficients, with 20 columns of 20 mels each.  <br>
#
# Once the feature vector has been recovered on the receiver side, we can apply any computation on it to guess the right class this sound belongs to. Today, we will simply reuse the simple KNN and LDA classifiers and look at what we already get.
#
# <font size=3 color=#FF0000> Important :</font> <br>
# The analyses that follow are given as food for thoughts. They are not given as step by step improvements of the classifier.
#
# <font size=5 color=#009999> 2.1. Creation of the dataset </font> <br>
#
# ``Feature_vector_DS`` is a class defined in ``classification/utils/audio_student.py``. <br>
# The functions ``__len__`` and ``__getitem__`` are implemented, meaning you can call :
# - ``len(myds)`` to get the number of sounds in it.
# - ``myds[classname,j]`` to get the melspectrogram of the ``j``-th sound from class ``classname``. <br>
#
# Two other useful functions are provided:
# - ``get_audiosignal`` returning the temporal audiosignal at the specified index.
# - ``display`` playing the sound and showing the associated mel-spectrogram at the specified index.
#
# <font size=3 color=#FF0000> Important :</font> <br>
# Before being able to run the cells below, you will have to reuse your functions from H1 to fill the missing lines in ``audio_student.py`` at ``###TO COMPLETE`` locations.

# %%
### TO RUN

"Creation of the dataset"
myds = Feature_vector_DS(dataset, Nft=512, nmel=20, duration=950, shift_pct=0.2)

"Some attributes..."
myds.nmel
myds.duration
myds.shift_pct
myds.sr
myds.data_aug
myds.ncol


idx = 0
myds.display(["fire", idx])

# %% [markdown]
# Running the cell above many times, you should notice it is always the beginning of the sound that is taken for creating the feature vector. ``shift_pct`` meaning *shift percentage* allows to roll the audio signal with a random factor upper bounded by this value. Change ``shift_pct`` to ``0.2`` and observe what happens.

# %%
### TO RUN
"Random split of 70:30 between training and validation"
train_pct = 0.7

featveclen = len(myds["fire",0]) # number of items in a feature vector
nitems = len(myds) # number of sounds in the dataset
naudio = dataset.naudio # number of audio files in each class
nclass = dataset.nclass # number of classes
nlearn = round(naudio * train_pct) # number of sounds among naudio for training

data_aug_factor = 1
class_ids_aug = np.repeat(classnames, naudio*data_aug_factor)

"Compute the matrixed dataset, this takes some seconds, but you can then reload it by commenting this loop and decommenting the np.load below"
X = np.zeros((data_aug_factor*nclass*naudio, featveclen))
for s in range(data_aug_factor):
    for class_idx, classname in enumerate(classnames):
        for idx in range(naudio):
            featvec = myds[classname, idx]
            X[s*nclass*naudio+class_idx*naudio+idx,:] = featvec       
np.save(fm_dir+"feature_matrix_2D.npy", X)

# X = np.load(fm_dir+"feature_matrix_2D.npy")

"Labels"
y = class_ids_aug.copy()

print('Shape of the feature matrix : {}'.format(X.shape))
print('Number of labels : {}'.format(len(y)))

print('Remember the convention shown for the toy example, the feature vectors are arranged on the rows.')
# Out:
# (array([-0.02027587, -0.02409757, -0.03789371, ..., -0.06911199,
#        -0.06907125, -0.10727496]), 11025)
# (array([ 0.04337287, -0.01455109,  0.04678272, ..., -0.06038683,
#        -0.02029398,  0.09743017]), 11025)
# (array([-0.01244073,  0.00759245,  0.01157681, ...,  0.02646731,
#         0.08569956,  0.00327576]), 11025)
# (array([-0.00216106, -0.07188071, -0.12281833, ..., -0.00885974,
#        -0.00230263,  0.01995942]), 11025)
# (array([-0.00522334, -0.0119316 ,  0.01676844, ..., -0.20890831,
#         0.01314557,  0.21250768]), 11025)
# (array([-0.00314567, -0.00717614, -0.00244649, ...,  0.14607673,
#        -0.22315262,  0.14930514]), 11025)
# (array([ 0.16227622,  0.03922049, -0.0382705 , ..., -0.06342089,
#        -0.12119489, -0.06011597]), 11025)
# (array([ 0.02560818, -0.0082821 , -0.01276954, ..., -0.17066619,
#         0.11638058,  0.04148174]), 11025)
# (array([-0.21643212, -0.20987652, -0.1717299 , ..., -0.53093257,
#        -0.53271737, -0.56266714]), 11025)
# (array([ 0.07068932,  0.15710008,  0.08573493, ...,  0.05036984,
#        -0.10130105,  0.08227065]), 11025)
# (array([-0.05470509,  0.16300829,  0.07814187, ...,  0.05469273,
#         0.16933693,  0.08796786]), 11025)
# (array([ 0.01596133, -0.14447417,  0.0286537 , ...,  0.57415585,
#        -0.62909387,  0.25913314]), 11025)
# (array([0.31529389, 0.37647877, 0.33266377, ..., 0.39870007, 0.23700307,
#        0.23582261]), 11025)
# (array([-0.21221635, -0.10554462,  0.11755077, ...,  0.06723114,
#         0.00222757,  0.0053133 ]), 11025)
# (array([ 0.15008109,  0.13458185,  0.17658085, ...,  0.00985392,
#        -0.00299435, -0.09051017]), 11025)
# (array([ 0.04167739,  0.06136896,  0.10791546, ...,  0.04075332,
#         0.05168246, -0.17043645]), 11025)
# (array([ 0.03677896, -0.00533157,  0.02389631, ...,  0.10092865,
#        -0.1127566 , -0.13049542]), 11025)
# (array([ 0.56385559,  0.23526253, -0.65668215, ...,  0.06519901,
#         0.15719881,  0.14060988]), 11025)
# (array([-0.05047815,  0.04531274, -0.00843487, ..., -0.01711867,
#        -0.03208826,  0.03193674]), 11025)
# (array([-0.00250618, -0.00839205,  0.00049724, ..., -0.00819269,
#         0.00089058, -0.01332787]), 11025)
# (array([-0.20601166, -0.11038412,  0.06074139, ..., -0.1882474 ,
#         0.00970892, -0.00086738]), 11025)
# (array([ 0.20503618,  0.19879568,  0.19885538, ..., -0.02821857,
#        -0.00235101,  0.05885723]), 11025)
# (array([-0.26902609, -0.62067345,  0.75743452, ..., -0.05462106,
#        -0.00174953,  0.03770137]), 11025)
# (array([ 0.02078174, -0.00884102,  0.0020076 , ...,  0.04146908,
#        -0.02672442,  0.03111696]), 11025)
# (array([ 0.2480146 ,  0.05553064, -0.14162949, ..., -0.11304285,
#         0.27838274, -0.01044947]), 11025)
# (array([-0.27727409,  0.04935563,  0.05035742, ...,  0.00886759,
#         0.06601644, -0.0874914 ]), 11025)
# (array([0.10108358, 0.02213487, 0.05116973, ..., 0.03387146, 0.00971639,
#        0.11516177]), 11025)
# (array([-0.14324833, -0.04120039,  0.03800966, ..., -0.25221818,
#        -0.19206961, -0.06754649]), 11025)
# (array([ 0.01394527, -0.04379691, -0.0475841 , ..., -0.26879145,
#        -0.34993037, -0.19814537]), 11025)
# (array([-0.00109028,  0.00109096, -0.00109165, ...,  0.0487539 ,
#        -0.03357425, -0.12579408]), 11025)
# (array([-0.00305809,  0.00156322, -0.00435432, ...,  0.00174769,
#         0.00093531,  0.00285214]), 11025)
# (array([ 0.23585973, -0.21651321,  0.17686239, ..., -0.02122106,
#         0.02077848, -0.02527794]), 11025)
# (array([-0.0467171 ,  0.03077341, -0.14018319, ...,  0.35046715,
#         0.3148186 , -0.23234219]), 11025)
# (array([-0.08472221, -0.00471714,  0.01960751, ...,  0.07472444,
#        -0.01340105, -0.0152259 ]), 11025)
# (array([-0.14912431,  0.00151842, -0.07695238, ..., -0.09485767,
#        -0.03198813, -0.08395623]), 11025)
# (array([ 0.0122936 ,  0.01947293, -0.01414167, ..., -0.08503755,
#        -0.08078851, -0.05431987]), 11025)
# (array([ 0.12932639, -0.12439405, -0.22691164, ..., -0.04417103,
#         0.26828392, -0.08817101]), 11025)
# (array([-0.18307209, -0.09380592, -0.13328069, ...,  0.08047724,
#         0.05662445,  0.04030884]), 11025)
# (array([-0.0218098 ,  0.25572354,  0.01650207, ...,  0.16468742,
#         0.1906206 ,  0.18097702]), 11025)
# (array([-0.08676334, -0.01323606,  0.27956849, ...,  0.36373625,
#         0.44136657,  0.17705998]), 11025)
# (array([-0.06420694,  0.04940207,  0.10855346, ...,  0.08079578,
#         0.17930571,  0.25533793]), 11025)
# (array([-0.02267688,  0.15920931,  0.18015769, ..., -0.07062523,
#        -0.06092582, -0.04456646]), 11025)
# (array([ 0.05465285, -0.00182111,  0.01529587, ...,  0.07254875,
#        -0.02658941, -0.12877929]), 11025)
# (array([-0.15681752, -0.18985118, -0.22510474, ..., -0.04009913,
#        -0.20117055,  0.02895753]), 11025)
# (array([-0.05719253, -0.11860074, -0.15273174, ...,  0.14400947,
#         0.24499769,  0.11672695]), 11025)
# (array([-0.22795643, -0.22906999, -0.18033935, ...,  0.02659344,
#         0.00180031, -0.00211246]), 11025)
# (array([ 0.03448727, -0.09573177, -0.37594476, ..., -0.3220831 ,
#         0.67661596,  0.37081933]), 11025)
# (array([-0.045654  ,  0.22433553,  0.32618148, ..., -0.04927869,
#        -0.03745243, -0.04752543]), 11025)
# (array([ 0.07989818,  0.17501411,  0.14977447, ...,  0.0319613 ,
#         0.22677083, -0.12941879]), 11025)
# (array([0.61395648, 0.1957361 , 0.14884217, ..., 0.10843531, 0.10059226,
#        0.09751392]), 11025)
# (array([0.12225727, 0.31183663, 0.11031591, ..., 0.19233006, 0.439225  ,
#        0.32444297]), 11025)
# (array([-0.11711429,  0.23516212,  0.00956819, ...,  0.05045511,
#         0.00221194,  0.01226933]), 11025)
# (array([ 0.01339164,  0.06958982,  0.04789644, ..., -0.00751351,
#        -0.00916515, -0.01086466]), 11025)
# (array([ 0.10885377,  0.02543945, -0.10923332, ...,  0.01003252,
#         0.02686184,  0.01244272]), 11025)
# (array([-0.12170614, -0.1166202 , -0.06359995, ..., -0.52320162,
#        -0.08772785,  0.07006827]), 11025)
# (array([-0.41546552,  0.01952409,  0.16623099, ...,  0.00476164,
#         0.00279419, -0.00244193]), 11025)
# (array([0.00934118, 0.01479035, 0.0029216 , ..., 0.2965549 , 0.42347814,
#        0.22395951]), 11025)
# (array([-0.12668499, -0.3398973 , -0.3814646 , ..., -0.0010128 ,
#         0.00135213, -0.00100853]), 11025)
# (array([-0.04923405, -0.20904284, -0.29848245, ..., -0.01661214,
#        -0.5972101 , -0.4795479 ]), 11025)
# (array([-0.39325203, -0.37930814, -0.61184514, ...,  0.08668262,
#        -0.00463247, -0.03353302]), 11025)
# (array([ 0.15181583,  0.14947032,  0.04893085, ...,  0.05403055,
#        -0.00645187, -0.08965072]), 11025)
# (array([ 0.32962199,  0.24908891,  0.13855167, ...,  0.05372206,
#        -0.08176753, -0.10926505]), 11025)
# (array([0.19666295, 0.32007085, 0.11529931, ..., 0.1304367 , 0.17670622,
#        0.09672117]), 11025)
# (array([-0.0813818 , -0.04334524,  0.01151985, ...,  0.03867499,
#         0.0286539 ,  0.02405212]), 11025)
# (array([-0.06477514, -0.04286846,  0.05634064, ...,  0.07351311,
#         0.00617544, -0.073474  ]), 11025)
# (array([-0.12856252,  0.25790862, -0.30933425, ...,  0.02629902,
#         0.00448831,  0.02241935]), 11025)
# (array([-0.19100352, -0.08323366,  0.08222589, ...,  0.4344256 ,
#         0.27339556,  0.2276068 ]), 11025)
# (array([-0.03215827, -0.21325131,  0.07333056, ..., -0.29786801,
#        -0.43265889, -0.22809059]), 11025)
# (array([ 0.19412895, -0.11170598, -0.07301577, ..., -0.05369217,
#         0.13040152,  0.03768988]), 11025)
# (array([-6.28850004e-05,  6.28798933e-05, -6.28747861e-05, ...,
#         3.14117867e-01,  2.13736271e-01,  3.07589091e-01]), 11025)
# (array([0.05958306, 0.04436002, 0.04183311, ..., 0.10355052, 0.31596783,
#        0.31054686]), 11025)
# (array([ 0.00518527, -0.09070495, -0.13991944, ...,  0.06712844,
#         0.19421597,  0.64534285]), 11025)
# (array([ 0.18111604, -0.10103286, -0.07277156, ...,  0.18173233,
#        -0.22877611, -0.22250358]), 11025)
# (array([-0.05816   , -0.25041016, -0.10982599, ..., -0.30614298,
#        -0.40685411, -0.37015712]), 11025)
# (array([-0.03065115,  0.04111645,  0.01836286, ..., -0.12250807,
#        -0.08994586, -0.09111962]), 11025)
# (array([ 0.03151498, -0.08109284, -0.05103327, ..., -0.29584128,
#        -0.33828735, -0.33932342]), 11025)
# (array([ 0.13924536, -0.04569795, -0.05187728, ..., -0.31405206,
#        -0.3739157 , -0.41258162]), 11025)
# (array([-4.58379903e-01, -2.84698434e-01, -5.16936515e-01, ...,
#        -2.09404087e-05, -1.69447116e-04,  4.81532021e-04]), 11025)
# (array([ 0.33464856,  0.38429154,  0.38963062, ..., -0.40163872,
#        -0.23112021, -0.07638636]), 11025)
# (array([-0.37815299, -0.12609253, -0.16470756, ..., -0.05045795,
#        -0.01152567, -0.00870428]), 11025)
# (array([-0.06634144, -0.04942458, -0.00709827, ...,  0.10645763,
#         0.06867515,  0.05180543]), 11025)
# (array([ 0.00195783, -0.00109638,  0.0038159 , ...,  0.01367481,
#         0.00722   ,  0.00788858]), 11025)
# (array([-0.01369823, -0.00820158, -0.00843692, ..., -0.03836831,
#        -0.0382595 , -0.02992009]), 11025)
# (array([-0.00786982, -0.0180339 , -0.00937445, ...,  0.05381103,
#         0.06848509,  0.05904398]), 11025)
# (array([-0.00510542, -0.00622453, -0.00287364, ...,  0.00723326,
#         0.00637494,  0.00788806]), 11025)
# (array([-0.00101341, -0.00287004,  0.01550794, ..., -0.06746637,
#        -0.06296905, -0.06533388]), 11025)
# (array([ 0.06194022,  0.01965584, -0.00158962, ..., -0.04454279,
#        -0.03641193, -0.02597954]), 11025)
# (array([-0.00344985, -0.0016414 , -0.00206545, ...,  0.0041902 ,
#         0.00810323,  0.00690236]), 11025)
# (array([ 0.00315045, -0.04129082,  0.03522045, ..., -0.08737809,
#        -0.07954181, -0.06324805]), 11025)
# (array([-0.02154863,  0.0087046 , -0.02644526, ...,  0.00170509,
#         0.01093134,  0.02299836]), 11025)
# (array([ 0.06521495,  0.05389694,  0.04256664, ..., -0.08315767,
#        -0.07090807, -0.09613172]), 11025)
# (array([-0.26084017, -0.25606624, -0.26185738, ...,  0.11129675,
#         0.13261218,  0.14249679]), 11025)
# (array([-0.06386504, -0.06508696, -0.0663024 , ...,  0.00156554,
#         0.00217157, -0.00351173]), 11025)
# (array([-0.00253339,  0.02700434, -0.00688483, ..., -0.0067747 ,
#        -0.00101705,  0.01372389]), 11025)
# (array([-0.06987852,  0.00749371,  0.05432562, ...,  0.0974399 ,
#         0.10585459,  0.17527066]), 11025)
# (array([-3.13606336e-05,  3.13459241e-05, -3.13311912e-05, ...,
#        -8.54194188e-02, -1.32041477e-01, -1.42331302e-01]), 11025)
# (array([0.02191829, 0.02958222, 0.03163311, ..., 0.010692  , 0.00957308,
#        0.00977413]), 11025)
# (array([ 0.10610458,  0.02097686,  0.04314577, ..., -0.19708027,
#        -0.15919436, -0.24167649]), 11025)
# (array([ 0.24101495,  0.17805684,  0.21770243, ..., -0.10065154,
#        -0.11421287, -0.14144274]), 11025)
# (array([-2.07174680e-04,  2.07183264e-04, -2.07191850e-04, ...,
#         2.65201893e-01,  3.03045898e-01,  1.90622997e-01]), 11025)
# (array([-0.34855918, -0.35160271, -0.35914738, ..., -0.00852138,
#         0.00649884,  0.00861338]), 11025)
# (array([-0.49580281, -0.49945036, -0.49684434, ..., -0.78569486,
#        -0.79068916, -0.80206749]), 11025)
# (array([-0.10981685, -0.11341045, -0.12341126, ..., -0.34636854,
#        -0.33853545, -0.33371915]), 11025)
# (array([-0.00348312,  0.00641187, -0.02521869, ...,  0.20622797,
#         0.17032777,  0.18315237]), 11025)
# (array([-0.26405528, -0.23767389, -0.10281686, ..., -0.3864087 ,
#        -0.33159008, -0.36496137]), 11025)
# (array([-0.15892754, -0.19448579, -0.22667607, ...,  0.08002109,
#         0.05272442,  0.04332348]), 11025)
# (array([-0.13340036, -0.12765067, -0.11734999, ...,  0.49446531,
#         0.51425963,  0.5253126 ]), 11025)
# (array([ 0.45951199,  0.44947833,  0.47394637, ..., -0.12550515,
#        -0.19583745, -0.23554105]), 11025)
# (array([0.19196289, 0.18158943, 0.16496358, ..., 0.19662602, 0.18527279,
#        0.17639806]), 11025)
# (array([-0.0141077 , -0.01165446, -0.00871246, ...,  0.00486908,
#        -0.00126454, -0.00119332]), 11025)
# (array([-0.03157338, -0.07815774, -0.0403658 , ...,  0.00203411,
#         0.02969679,  0.03001643]), 11025)
# (array([0.00415784, 0.00530383, 0.0078994 , ..., 0.00729327, 0.00122663,
#        0.00670624]), 11025)
# (array([-0.18573008, -0.19644003, -0.19936774, ...,  0.09447159,
#         0.06542122,  0.06840397]), 11025)
# (array([-0.03516721, -0.02754345, -0.03353877, ..., -0.14285686,
#        -0.15725157, -0.16509956]), 11025)
# (array([ 0.13317283,  0.13409844,  0.14740507, ..., -0.21696878,
#        -0.31066642, -0.363805  ]), 11025)
# (array([-0.01116241, -0.04936089, -0.07234308, ..., -0.02705122,
#        -0.0264918 ,  0.01092405]), 11025)
# (array([-0.32273965, -0.32819939, -0.3188338 , ..., -0.06466433,
#        -0.0686446 , -0.0765257 ]), 11025)
# (array([ 0.00651345, -0.07219076, -0.06111029, ..., -0.15728986,
#        -0.23138708, -0.18694143]), 11025)
# (array([0.02238742, 0.02043022, 0.02509515, ..., 0.01139487, 0.01654431,
#        0.01168284]), 11025)
# (array([ 7.14972505e-05,  1.53950092e-03, -3.45190937e-05, ...,
#         9.02694988e-03,  3.35352788e-02, -7.42509203e-03]), 11025)
# (array([-0.00508631, -0.00325008, -0.01163765, ...,  0.04075277,
#         0.04547247,  0.05029992]), 11025)
# (array([-0.04886964, -0.05641763, -0.05759981, ...,  0.01385644,
#         0.01424337,  0.01204048]), 11025)
# (array([-0.08919849, -0.08891964, -0.05814967, ..., -0.02520078,
#        -0.01559013, -0.03274784]), 11025)
# (array([ 0.00975472, -0.01817781, -0.01068301, ..., -0.27484055,
#        -0.02892853,  0.10971799]), 11025)
# (array([-0.09287603, -0.13961695, -0.14073938, ..., -0.06946424,
#        -0.01159517,  0.0913784 ]), 11025)
# (array([-0.00139838,  0.00645456,  0.00628345, ...,  0.00033543,
#        -0.0642697 , -0.25551015]), 11025)
# (array([-0.38901487, -0.40794564, -0.19971631, ..., -0.08737698,
#        -0.13351461, -0.17057309]), 11025)
# (array([-0.00985235, -0.01368206, -0.0170273 , ...,  0.03592818,
#        -0.12004691, -0.27563665]), 11025)
# (array([ 0.05583197,  0.05574313,  0.04130029, ...,  0.43522304,
#        -0.05768208,  0.01503079]), 11025)
# (array([ 0.00333431,  0.002725  ,  0.00073738, ..., -0.02980619,
#        -0.0303474 , -0.02966538]), 11025)
# (array([ 0.06082827,  0.01972343,  0.03949028, ...,  0.02914369,
#        -0.00575866,  0.00529753]), 11025)
# (array([0.16713026, 0.07267602, 0.11619798, ..., 0.21266359, 0.19673557,
#        0.19118343]), 11025)
# (array([ 0.42923027,  0.18336919,  0.39194855, ...,  0.26186647,
#         0.00111221, -0.1353289 ]), 11025)
# (array([ 0.03913741,  0.05320422,  0.03768623, ..., -0.13465397,
#         0.20229535, -0.00983426]), 11025)
# (array([ 2.27822497e-01,  2.10283626e-04, -7.45706545e-02, ...,
#        -4.24479214e-03, -1.74723690e-02,  1.96519322e-02]), 11025)
# (array([-0.05582766,  0.08388499, -0.03447177, ...,  0.16965496,
#         0.21299648, -0.38260913]), 11025)
# (array([-0.08958196,  0.07820078,  0.08780598, ..., -0.02581257,
#        -0.10223956, -0.01391267]), 11025)
# (array([-0.70572058, -0.69201891, -0.75220333, ...,  0.02287055,
#        -0.07014136, -0.11834493]), 11025)
# (array([ 0.03840096, -0.01623663, -0.0121728 , ...,  0.13031675,
#         0.08284755, -0.00128082]), 11025)
# (array([-0.11562458, -0.04816471, -0.01278241, ..., -0.02974468,
#        -0.01389212, -0.01532629]), 11025)
# (array([ 0.02162111, -0.00457049,  0.07785101, ..., -0.04305482,
#        -0.26467121,  0.09430334]), 11025)
# (array([-0.0939249 ,  0.00783026,  0.00485086, ..., -0.02884071,
#        -0.00528544, -0.10440342]), 11025)
# (array([ 0.19387832,  0.00319667, -0.03476148, ..., -0.04964062,
#        -0.09549179, -0.06213647]), 11025)
# (array([-3.34191066e-03, -3.16276599e-04, -4.40452501e-03, ...,
#         9.98318883e-02,  3.59519217e-01,  1.66624817e-01]), 11025)
# (array([-0.1082682 ,  0.01753624,  0.17179747, ..., -0.20526657,
#        -0.24300593, -0.13529703]), 11025)
# (array([ 0.01693771,  0.01505853,  0.00444803, ..., -0.00738082,
#         0.00211663,  0.01392479]), 11025)
# (array([-0.02706374, -0.01453747, -0.10903684, ..., -0.02434786,
#        -0.01448136,  0.01670554]), 11025)
# (array([ 0.00317687, -0.00082215,  0.00597322, ...,  0.0122509 ,
#         0.01251956,  0.01312439]), 11025)
# (array([-0.01811559, -0.02966779, -0.02249418, ..., -0.07513853,
#        -0.12565703, -0.00735995]), 11025)
# (array([-0.06299663, -0.02452258, -0.02533624, ...,  0.12320962,
#         0.46947293,  0.2349844 ]), 11025)
# (array([-0.00712284,  0.15360034, -0.0361362 , ...,  0.03134949,
#         0.01684091,  0.13355491]), 11025)
# (array([ 0.01892402, -0.05298183, -0.06003898, ...,  0.31189159,
#         0.29380832, -0.13838405]), 11025)
# (array([-0.07670935, -0.04592434,  0.02467267, ..., -0.21668024,
#        -0.31211538, -0.38567671]), 11025)
# (array([-0.03130981, -0.16523779, -0.27025833, ...,  0.01423487,
#         0.0281288 ,  0.0274132 ]), 11025)
# (array([-0.13711105, -0.14685153, -0.05052318, ...,  0.05468082,
#         0.06534436,  0.05187797]), 11025)
# (array([-6.32848354e-05,  6.32875367e-05, -6.32902385e-05, ...,
#        -2.03986422e-01, -4.18253695e-01, -5.72331400e-01]), 11025)
# (array([-0.02738646, -0.032744  , -0.02394629, ..., -0.02657728,
#        -0.0041693 ,  0.06659817]), 11025)
# (array([ 0.03947903,  0.01229801,  0.01934649, ...,  0.18268517,
#        -0.25762547,  0.25861053]), 11025)
# (array([-2.22224898e-05,  2.22416694e-05, -2.22608565e-05, ...,
#        -4.46109741e-03, -1.28522406e-03,  9.65567103e-03]), 11025)
# (array([ 2.14251237e-05, -2.14185735e-05,  2.14120228e-05, ...,
#        -2.16909837e-02,  1.00861675e-02,  4.93709782e-02]), 11025)
# (array([-0.03512955, -0.04352222, -0.04878449, ...,  0.22984549,
#         0.06173717,  0.15498895]), 11025)
# (array([-0.58498762, -0.7241435 , -0.64387058, ..., -0.41251693,
#        -0.59223553, -0.36084071]), 11025)
# (array([ 0.69202455,  0.57432939,  0.74287879, ..., -0.09946892,
#        -0.14371654, -0.16399168]), 11025)
# (array([ 0.05173353,  0.0691679 ,  0.00543323, ...,  0.06316028,
#        -0.09620185, -0.04083371]), 11025)
# (array([0.35380878, 0.17128418, 0.02386227, ..., 0.08836542, 0.12230796,
#        0.07248717]), 11025)
# (array([-0.14772581, -0.02180219, -0.10977757, ...,  0.21874941,
#         0.09214752,  0.36036931]), 11025)
# (array([-0.06492736, -0.04493536, -0.16583894, ..., -0.13649357,
#        -0.18447651, -0.14958905]), 11025)
# (array([-0.15537124, -0.17864231, -0.19612518, ...,  0.31858098,
#         0.26012529,  0.25084694]), 11025)
# (array([-0.18562414, -0.21166531, -0.19416575, ...,  0.03128814,
#         0.06031855,  0.07374171]), 11025)
# (array([ 0.03217889,  0.0028391 , -0.02713065, ...,  0.11058977,
#         0.11739822,  0.12316733]), 11025)
# (array([-0.42562586, -0.53821832, -0.6498828 , ...,  0.33238022,
#         0.33235363,  0.32377911]), 11025)
# (array([-0.02996127, -0.0151471 ,  0.01255563, ...,  0.33278382,
#         0.34106065,  0.33799329]), 11025)
# (array([-0.98219585,  0.98218997, -0.9821841 , ..., -0.94382356,
#         0.94374528, -0.9436669 ]), 11025)
# (array([ 0.56630361,  0.66532219,  0.53922625, ..., -0.06166131,
#        -0.06859153, -0.03326342]), 11025)
# (array([-0.06046258, -0.03933751, -0.00672337, ...,  0.0401437 ,
#        -0.08569828, -0.19819103]), 11025)
# (array([ 0.14359999, -0.16355494, -0.53956795, ..., -0.03351565,
#        -0.22801497, -0.23398962]), 11025)
# (array([-0.50484072, -0.55951554, -0.56642113, ...,  0.11990724,
#         0.14151345,  0.32226378]), 11025)
# (array([-0.09464803, -0.03188574,  0.01046267, ...,  0.2284103 ,
#         0.0474382 , -0.25246364]), 11025)
# (array([ 0.18035586,  0.32696009,  0.38751953, ..., -0.10961648,
#        -0.16512477, -0.21626694]), 11025)
# (array([-9.18920110e-02, -1.78309690e-01, -1.75968070e-01, ...,
#         1.52495022e-05, -1.52484274e-05,  1.52473527e-05]), 11025)
# (array([ 0.00843399,  0.07019812,  0.1375441 , ..., -0.03175208,
#        -0.08074422, -0.06973119]), 11025)
# (array([-0.15124149, -0.1537225 , -0.15476407, ...,  0.01848364,
#         0.02592927,  0.03322486]), 11025)
# (array([ 0.1682102 ,  0.202432  ,  0.22811267, ...,  0.00253837,
#        -0.00452845, -0.01161967]), 11025)
# (array([-0.01469871, -0.0191363 , -0.0173623 , ..., -0.21042129,
#        -0.25226686, -0.28782899]), 11025)
# (array([0.1611517 , 0.11903046, 0.11720612, ..., 0.17954824, 0.16426154,
#        0.18830595]), 11025)
# (array([ 0.0108152 , -0.06315197, -0.13300181, ..., -0.08884203,
#        -0.06173053,  0.06911011]), 11025)
# (array([-0.15522159, -0.15724837, -0.14858815, ..., -0.0438351 ,
#        -0.12395802, -0.10866276]), 11025)
# (array([-0.07057974, -0.07518904, -0.03997183, ..., -0.35866959,
#        -0.36518145, -0.37439656]), 11025)
# (array([-0.09732211, -0.08673485, -0.09621055, ...,  0.14730069,
#         0.14482233,  0.11778251]), 11025)
# (array([ 8.93819802e-05, -5.76296678e-03,  6.76292610e-04, ...,
#        -6.62722148e-02, -8.87202706e-02, -7.28011562e-02]), 11025)
# (array([-0.15647773, -0.19601393, -0.2001619 , ...,  0.4554523 ,
#         0.50447296,  0.54019558]), 11025)
# (array([-0.14970524, -0.18646587, -0.2326695 , ..., -0.4470736 ,
#        -0.41195746, -0.37033531]), 11025)
# (array([ 0.10203341,  0.09860204,  0.06023585, ..., -0.08555211,
#        -0.10833769, -0.12609305]), 11025)
# (array([0.36978934, 0.36458694, 0.34404978, ..., 0.05236208, 0.04374303,
#        0.05936606]), 11025)
# (array([ 0.46961591,  0.46446644,  0.43496351, ..., -0.02328201,
#        -0.03583149, -0.04348306]), 11025)
# (array([0.26792626, 0.2279756 , 0.20910465, ..., 0.06251629, 0.07156471,
#        0.05816719]), 11025)
# (array([-0.26822741, -0.26600203, -0.28593608, ...,  0.05990904,
#        -0.0304973 , -0.02777587]), 11025)
# (array([ 0.23955482,  0.28404264,  0.23688625, ..., -0.00090033,
#        -0.02291045, -0.07715453]), 11025)
# (array([-0.21376378, -0.20167143, -0.22405906, ..., -0.35156949,
#        -0.39969424, -0.40478402]), 11025)
# (array([-0.11803472, -0.0117297 , -0.00679339, ...,  0.24932835,
#         0.16277602,  0.05531302]), 11025)
# (array([-0.03249929, -0.05802347, -0.10290092, ..., -0.00731804,
#        -0.59714887, -0.86682725]), 11025)
# Shape of the feature matrix : (200, 400)
# Number of labels : 200
# Remember the convention shown for the toy example, the feature vectors are arranged on the rows.

# %% [markdown]
# You might notice that ``feature_matrix_2D.npy`` has been saved in ``data/feature_matrices/`` and can now be loaded instead of recomputing it at every run.

# %% [markdown]
# <font size=5 color=#009999> 2.2. First audio classification, metrics and dataset splitting </font> <br>
#
# For now we have only prepared the dataset, it remains to feed it to the classifiers. <br>

# %%
### TO RUN
K = 6 # Number of neighbours for the KNN
model_knn = KNeighborsClassifier(n_neighbors=K, weights='distance', algorithm='auto', metric='minkowski') #We explicitly write the default parameters of this KNN classifier once so that you know they exist and can be changed

model_lda = LDA(solver='svd', shrinkage=None, priors=None, n_components=None, store_covariance=False, tol=0.0001, covariance_estimator=None) #We explicitly write the default parameters of this LDA classifier once so that you know they exist and can be changed

# %% [markdown]
# As for the toy example, we keep the ``accuracy`` and ``confusion matrix`` as performance metrics. <br>
#
# Note that here we are not especially interested in a model selection hence we only split the dataset in training and testing parts but we don't split the training set in learning/validation parts. The models are trained on the entire training set.

# %%
### TO RUN
"Shuffle then split the dataset into training and testing subsets"
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y) # random_state=1
print('Shape of the training matrix : {}'.format(X_train.shape))
print('Number of training labels : {}'.format(len(y_train)))

model_knn.fit(X_train, y_train)
model_lda.fit(X_train, y_train)

prediction_knn = model_knn.predict(X_test)
prediction_lda = model_lda.predict(X_test)
accuracy_knn = accuracy (prediction_knn, y_test)
accuracy_lda = accuracy (prediction_lda, y_test)

print('Accuracy of KNN with fixed train/validation sets : {:.1f}%'.format(100*accuracy_knn))
show_confusion_matrix (prediction_knn, y_test, classnames)
print('Accuracy of LDA with fixed train/validation sets : {:.1f}%'.format(100*accuracy_lda))
show_confusion_matrix (prediction_lda, y_test, classnames)
# Out:
# Shape of the training matrix : (140, 400)
# Number of training labels : 140
# Accuracy of KNN with fixed train/validation sets : 53.3%
# Accuracy of LDA with fixed train/validation sets : 46.7%

# %% [markdown]
# **Questions**:
# - What would be the expected accuracy if the label predictions were picked at random?
# - What do you observe in this confusion matrix? Run again the cell above, i.e., Reapply the ``train_test_split`` and tell if your observations are robust.

# %% [markdown]
# ### TO COMPLETE
# # Answer the questions above
#
# If the predictions were random, and there were N labels, we would expect to be right 1 time over N.
#
# This is not the case here : we can see that in the confusion matrixes, the correct labels are identified more often than not.
# Indeed, diagonal entries are highest of each line. However, it is clearly not perfect as the accuracy is around 50% for both classifiers.
# This can also be seen in the matrixes : for each line, the non-diagonal entries approximately sum up to the value of the diagonal entry.
# This shows that the classifier is wrong 50% of the time ...
#
# It should be noted that the accuracy and the confusion matrixes DO NOT represent the same information, but here they concur on the fact that the classifiers are bad.

# %% [markdown]
# Play with the ``classname`` and the index ``idx`` to pick feature vectors in the dataset ``myds``, listen to the audio associated to the feature vector, and check if you would have been able to predict the right class by your own. Then compare with the prediction given by your classifier.

# %%
### TO RUN
idx = 5
classname = "handsaw"  # classnames : birds, chainsaw, fire, handsaw, helicopter
myds.display([classname, idx])
thisfv = myds[classname,idx].reshape(-1)

# this artefact is necessary because the 'predict' function expects a matrix_like input.
mat = np.zeros((2, len(thisfv)))
mat[0] = thisfv

prediction_knn = model_knn.predict(mat)
prediction_lda = model_lda.predict(mat)

print('Class predicted by KNN:', prediction_knn[0])
print('Class predicted by LDA:', prediction_lda[0])
# Out:
# (array([ 0.08912219,  0.022433  , -0.04100581, ..., -0.04796905,
#        -0.05392556, -0.06309861]), 11025)
# Class predicted by KNN: handsaw
# Class predicted by LDA: helicopter

# %% [markdown]
# Furthermore, when training a model and comparing different settings, there is a risk that we will end up choosing optimal parameters that only render good result on our specific case of training and validation set, but ``do not generalize well for additional data``. This is called ``overfitting on the validation set``. To alleviate this, we can perform ``cross-validation (CV)``. A basic approach named ``K-fold CV`` involves partitioning the dataset in ``K`` "folds" (subsets) and repetitvely do the following procedure:
#
# - Train the model using `K-1` folds as the training data.
# - Test the model using the last fold as the validation data.
#
# The overall performance on each fold is then averaged to obtain the final performance metrics.

# %%
### TO RUN
n_splits = 5
kf = StratifiedKFold(n_splits=n_splits,shuffle=True)

accuracy_knn = np.zeros((n_splits,))
accuracy_lda = np.zeros((n_splits,))
for k, idx in enumerate(kf.split(X_train,y_train)):
  (idx_learn, idx_val) = idx
  model_knn.fit(X_train[idx_learn], y_train[idx_learn])
  prediction_knn = model_knn.predict(X_train[idx_val])
  accuracy_knn[k] = accuracy(prediction_knn, y_train[idx_val])

  model_lda.fit(X_train[idx_learn], y_train[idx_learn])
  prediction_lda = model_lda.predict(X_train[idx_val])
  accuracy_lda[k] = accuracy(prediction_lda, y_train[idx_val])

print('Mean accuracy of KNN with 5-Fold CV: {:.1f}%'.format(100*accuracy_knn.mean()))
print('Std deviation in accuracy of KNN with 5-Fold CV: {:.1f}%'.format(100*accuracy_knn.std()))

print('Mean accuracy of LDA with 5-Fold CV: {:.1f}%'.format(100*accuracy_lda.mean()))
print('Std deviation in accuracy of LDA with 5-Fold CV: {:.1f}%'.format(100*accuracy_lda.std()))
# Out:
# Mean accuracy of KNN with 5-Fold CV: 43.6%
# Std deviation in accuracy of KNN with 5-Fold CV: 12.2%
# Mean accuracy of LDA with 5-Fold CV: 38.6%
# Std deviation in accuracy of LDA with 5-Fold CV: 7.3%

# %% [markdown]
# <font size=5 color=#009999> 2.3. Scale mismatch and countermeasure </font> <br>
#
# In real conditions, you will most probably have a different scale between the feature vectors used for training (in simulation) and the ones you feed in your model to make predictions.
# This scale mismatch between model training and prediction is difficult to prevent because it depends on multiple factors such as the audio source power, its distance to the microphone, the telecommunication distance. <br>
#
# Below, we illustrate the link between the volume of the audio and its distance to the origin of the feature space. At different emission distances, the exact same sound would be heard at a different volume and the associated feature vector would be located at another position in the *feature space*. Eventually, this would result in a completely different classification, which is undesirable.
#
# <center> <img src="figs/norms.png" alt="" width="350"/> </center>
#
# ### Questions:
#
# - How could you avoid this dependency on the volume of the sound?
# - What is represented in the hatched centered area? How would you classify feature vectors in this area?

# %% [markdown]
# ### TO COMPLETE
# # Answer the questions above
#
# The feature vectors could be normalized.
#
# The hatched center area could represent noise, or signals for which the power is very small (around noise level).
# These feature vectors should not be classified as they are polluted by noise. They should NOT be normalized !
# A threshold could be set around which signals would not be normalized and classified (epsilon on the graph).

# %% [markdown]
# Play with the ``dB_mismatch`` variable here below and observe its effect on the confusion matrix.
#
# On which part of the dataset are we computing this confusion matrix?

# %%
### TO RUN
dB_mismatch = 0 # Play with this value
X_val_scaled = X_train[idx_val]*10**(-dB_mismatch/20)

model_knn = KNeighborsClassifier(n_neighbors=10) 
model_knn.fit(X_train[idx_learn], y_train[idx_learn])
prediction_knn = model_knn.predict(X_val_scaled)
show_confusion_matrix (prediction_knn, y_train[idx_val], classnames)
accuracy_knn = accuracy (prediction_knn, y_train[idx_val])
print('Accuracy of KNN: {:.1f}%'.format(100*accuracy_knn))
# Out:
# Accuracy of KNN: 46.4%

# %% [markdown]
# The simplest countermeasure we can think of is to normalise the feature vector (i.e. unitize its norm) prior to use, both for training and testing. Remember how this normalization could be visualized in ``hands_on_classif1_toy_student.ipynb`` <br>
# Play again with the ``dB_mismatch`` variable here below and observe its effect on the confusion matrix.

# %%
### TO RUN
dB_mismatch = -5 # Play with this value

X_learn_normalised = X_train[idx_learn]/ np.linalg.norm(X_train[idx_learn], axis=1, keepdims=True)
model_knn = KNeighborsClassifier(n_neighbors=10, weights='distance') 
model_knn.fit(X_learn_normalised, y_train[idx_learn])

X_val_scaled = X_train[idx_val]*10**(-dB_mismatch/20)
X_val_normalised = X_val_scaled/ np.linalg.norm(X_val_scaled, axis=1, keepdims=True)

prediction_knn = model_knn.predict(X_val_normalised)
show_confusion_matrix (prediction_knn, y_train[idx_val], classnames)
accuracy_knn = accuracy (prediction_knn, y_train[idx_val])
print('Accuracy of KNN: {:.1f}%'.format(100*accuracy_knn))
# Out:
# Accuracy of KNN: 50.0%

# %% [markdown]
# **Question**:
# - What will happen with this normalisation countermeasure when there is no sound around the microphone? Is this desirable? How could you deal with it?

# %% [markdown]
# ### TO COMPLETE
# # Answer the questions above
#
# Noise will be amplified by normalization, and this is awful. We don't want to classify noise obviously.
# A way to deal with this would be to set a threshold below which feature vectors are not normalized and not dealt with,
# in order to prevent misclassification of noise or signals at noise level.

# %% [markdown]
# <font size=5 color=#009999> 2.4. Dimensionality reduction </font> <br>
#
# It is sometimes good practice to reduce the dimensionality of a signal in order to get the main components of their distribution. A motivation is that usual norms behave counter-inuitively in high dimension. It also further reduces the memory cost of the feature vector. To reduce the dimensionality, we will use the ``Principal component analysis (PCA)`` proposed by sklearn. See the [associated Wikipedia page](https://en.wikipedia.org/wiki/Principal_component_analysis). Recall: the PCA consists in reducing the dimensionality of data vectors encoded in $\boldsymbol X \in \mathbb R^{d\times N}$ to only $p \ll d$ dimensions as
#
# $$
#     \boldsymbol Y = \boldsymbol V_p^\top \boldsymbol X \in \mathbb R^{p\times N},
# $$
#
# where the SVD of the covariance matrix writes as $\hat{\boldsymbol\Sigma}_{\boldsymbol X} = \frac{1}{d} \boldsymbol{XX}^\top = \boldsymbol{U\Sigma V}^\top$, and $\boldsymbol V_p$ is the subselection of the first $p$ columns of $\boldsymbol V$.
#
# For our application, reducing the dimensionality of the data can be helpful for compressing the packet size to be transmitted wirelessly. Indeed, once learned during training, $\boldsymbol V_p$ can be hardcoded on the transmitter side.
#
# Starting with a PCA to 2D for visualization, see how hard it is to separate the classes.

# %%
### TO RUN
n=2 # Number of principal components kept
pca = PCA(n_components=n,whiten=True)
X_learn_reduced = pca.fit_transform(X_train[idx_learn])
X_val_reduced = pca.transform(X_train[idx_val])

print('Shape of the reduced training matrix : {}'.format(X_learn_reduced.shape))

y_train_num = np.zeros(y_train.shape)
for i, classname in enumerate(classnames):
    y_train_num[y_train==classname] = i

K = 10
model_knn = KNeighborsClassifier(n_neighbors=K)
model_knn.fit(X_learn_reduced, y_train_num[idx_learn])
prediction_knn = model_knn.predict(X_val_reduced)
accuracy_knn = accuracy(prediction_knn, y_train_num[idx_val])

model_lda = LDA()
model_lda.fit(X_learn_reduced, y_train_num[idx_learn])
prediction_lda = model_lda.predict(X_val_reduced)
accuracy_lda = accuracy(prediction_lda, y_train_num[idx_val])

fig = plt.figure()
axs = [fig.add_axes([0.0, 0.0, 0.4, 0.9]), fig.add_axes([0.6, 0.0, 0.4, 0.9])]
plot_decision_boundaries(X_learn_reduced,y_train_num[idx_learn],ax=axs[0],model=model_knn,legend=classnames,title='KNN')
plot_decision_boundaries(X_learn_reduced,y_train_num[idx_learn],ax=axs[1],model=model_lda,legend=classnames,title='LDA')
plt.show()
# Out:
# Shape of the reduced training matrix : (112, 2)

# %% [markdown]
# **Question**:
# - From the decision boundaries shown here above, can you explain why the ``handsaw`` class is less often chosen than the other classes for the ``KNN`` classifier?

# %% [markdown]
# ### TO COMPLETE
# # Answer the questions above
#
# It can be seen that the handsaw class contains way less points than the others.
# This might be due to the fact that that class shares similar features to others and it is therefore harder to differentiate it.

# %%
### TO RUN
n=5 # Number of principal components kept
pca = PCA(n_components=n,whiten=True)
X_learn_reduced = pca.fit_transform(X_train[idx_learn])
X_val_reduced = pca.transform(X_train[idx_val])

print('Shape of the reduced learning matrix : {}'.format(X_learn_reduced.shape))

K = 10
model_knn = KNeighborsClassifier(n_neighbors=K, weights='distance')
model_knn.fit(X_learn_reduced, y_train[idx_learn])
prediction_knn = model_knn.predict(X_val_reduced)
accuracy_knn = accuracy(prediction_knn, y_train[idx_val])

model_lda = LDA()
model_lda.fit(X_learn_reduced, y_train[idx_learn])
prediction_lda = model_lda.predict(X_val_reduced)
accuracy_lda = accuracy(prediction_lda, y_train[idx_val])

print('Accuracy of the KNN : {:.1f}%'.format(100*accuracy_knn))
show_confusion_matrix(prediction_knn, y_train[idx_val], classnames)
print('Accuracy of the LDA : {:.1f}%'.format(100*accuracy_lda))
show_confusion_matrix(prediction_lda, y_train[idx_val], classnames)
# Out:
# Shape of the reduced learning matrix : (112, 5)
# Accuracy of the KNN : 42.9%
# Accuracy of the LDA : 42.9%

# %% [markdown]
# <font size=5 color=#009999> 2.5. Analysis of the hyperparameters </font> <br>
#
# Finally, we can inspect the influence of ``hyperparameters`` as we did for the toy example. <br>
# Let us start by analyzing the influence of the number of neighbours $K$ in the KNN.

# %%
### TO RUN
Ks = np.arange(6,15, 1)
accuracies_knn = np.zeros((len(Ks), n_splits))
for i,K in enumerate(Ks):
    model_knn = KNeighborsClassifier(n_neighbors=K, weights='distance') 
    for k, idx in enumerate(kf.split(X_train,y_train)):
            (idx_learn, idx_val) = idx
            model_knn.fit(X_train[idx_learn], y_train[idx_learn])
            prediction_knn = model_knn.predict(X_train[idx_val])
            accuracies_knn[i,k] = accuracy(prediction_knn, y_train[idx_val])
means_knn = accuracies_knn.mean(axis=1)
stds_knn = accuracies_knn.std(axis=1)

"Plot"
plt.figure(figsize=(6,3))
plt.plot(Ks, means_knn, '.-b', label='KNN')
plt.fill_between(Ks,means_knn-stds_knn,means_knn+stds_knn,alpha=0.2,color='b')
plt.ylim(0,1)
plt.xlabel('K')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# Here we consider both ``K`` and the number of principal components ``n``.

# %%
### TO RUN
Ks = np.arange(1,10)
n_comps = np.arange(2, 15) # number of principal components kept for the PCA
accuracies_knn = np.zeros( (len(Ks), len(n_comps)) )
accuracies_lda = np.zeros(len(n_comps)) 

for j, n in enumerate(n_comps):
    for idx_learn, idx_val in kf.split(X_train,y_train):
        pca = PCA(n_components=n,whiten=True)
        X_learn_reduced = pca.fit_transform(X_train[idx_learn])
        X_val_reduced = pca.transform(X_train[idx_val])
        for i,K in enumerate(Ks):
            model_knn = KNeighborsClassifier(n_neighbors=K)
            model_knn.fit(X_train[idx_learn], y_train[idx_learn])
            prediction_knn = model_knn.predict(X_train[idx_val])
            accuracies_knn[i,j] += accuracy(prediction_knn, y_train[idx_val])
        
        model_lda = LDA()
        model_lda.fit(X_train[idx_learn], y_train[idx_learn])
        prediction_lda = model_lda.predict(X_train[idx_val])
        accuracies_lda[j] += accuracy(prediction_lda, y_train[idx_val])

accuracies_knn /= n_splits
accuracies_lda /= n_splits

fig = plt.figure(figsize=(10,4))
axs = [fig.add_axes([0.0, 0.0, 0.4, 0.9]), fig.add_axes([0.6, 0.0, 0.4, 0.9])]

im0 = axs[0].imshow(100*accuracies_knn, cmap='jet', origin='lower')
cbar = fig.colorbar(im0, ax=axs[0])
cbar.set_label('Accuracy (%)')
axs[0].set_xlabel('n_PCA')
axs[0].set_ylabel('K')
axs[0].set_xticks(list(np.arange(len(n_comps))))
axs[0].set_xticklabels(list(n_comps))
axs[0].set_yticks(list(np.arange(len(Ks))))
axs[0].set_yticklabels(list(Ks))
axs[0].set_title('KNN')

axs[1].plot(accuracies_lda*100)
axs[1].set_xlabel('n_PCA')
axs[1].set_ylabel('Accuracy (%)')
axs[1].set_title('LDA')
plt.show()

# %% [markdown]
# **Question**:
# - Do you observe some dependency of the accuracy on these parameters? If so, which one(s)? If not, discuss what it tells about the considered model.

# %% [markdown]
# ### TO COMPLETE
# # Answer the question above
#
# For KNN, it seems that keeping a high amount of dimensions is better, as the classification is best with 12 or more dimensions.
# The best results are also attained when K is 4, 5 or 6. It shows that we should not take too much neighbors into account as the dataset might be too small.
#
# For LDA, the accuracy is very volatile with respect the number of dimensions... How to explain this?

# %% [markdown]
# <font size=5 color=#009999> 2.6. Augmenting the data </font> <br>
#
# In order to make our classifier more robust to some common transformations of the audio signal such as ``time shift``, ``AWGN``, or a ``transfer function``, an idea consists in feeding the classifier with such transformations. A popular approach is to create new feature vectors based on transformed versions of the sounds from the original dataset, this is called ``data augmentation``. Data augmentation is also often used when there is few data to train a model. <br>
#
# The functions to augment your data are written in ``utils/audio_student.py``, we already implemented ``time_shift``, ``echo`` and ``spectro_aug_timefreq_masking`` for you. Try to implement ``scaling``, ``add_noise``, ``filter``, ``add_bg`` and even more data augmentation techniques if you want, and check their working in the cell below. <br>
#
# <u>Tip</u>: to avoid restarting the notebook kernel for each modification, you can temporarily insert the ``AudioUtil`` class in a new cell and make your tests until it is working as expected.

# %%
### TO RUN
myds.data_aug = None # Ensure

cls_index = ["birds", 4]

AudioUtilInst = AudioUtil()

sound = dataset.__getitem__(cls_index)
name = dataset.__getname__(cls_index)
audio = AudioUtilInst.open(sound)

AudioUtilInst.play(audio)
audio2 = AudioUtilInst.resample(audio, 11025)
audio2 = AudioUtilInst.pad_trunc(audio2, 5000)

print(dataset.__getitem__(('birds', 1)))

audio3 = AudioUtilInst.time_shift(audio2, 0.4)
audio4 = AudioUtilInst.scaling(audio2) 
audio5 = AudioUtilInst.add_noise(audio2, sigma=1e-2)
audio6 = AudioUtilInst.echo(audio2, 3)
audio7 = AudioUtilInst.add_bg(audio2, dataset)

melspec = AudioUtilInst.melspectrogram(audio2, fs2=11025)
melspec2 = AudioUtilInst.spectro_aug_timefreq_masking(melspec, max_mask_pct=0.1)

"Plot"
fig = plt.figure(figsize=(15,4))
ax1 = fig.add_axes([0.05, 0.05, 0.28, 0.9])
ax2 = fig.add_axes([0.38, 0.05, 0.28, 0.9])
ax3 = fig.add_axes([0.7, 0.05, 0.28, 0.9])

ax1.plot(audio2[0], label='Original')
ax1.plot(audio3[0]+1, label='Time shifted')
ax1.plot(audio4[0]+2, label='Rescaled')
ax1.plot(audio5[0]+3, label='Noisy')
ax1.plot(audio6[0]+4, label='With echos')
ax1.plot(audio7[0]+5, label='With background sound')
ax1.legend()

plot_specgram(melspec, ax2, is_mel=True, title=name, tf = len(audio2[0])/audio2[1])
ax2.set_title('Melspectrogram')
plot_specgram(melspec2, ax3, is_mel=True, title=name, tf = len(audio2[0])/audio2[1])
ax3.set_title('Corrupted melspectrogram')
plt.show()
# Out:
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\birds_1.wav
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\fire_10.wav

# %% [markdown]
# We can now create a new augmented dataset and observe if the classification results improve.

# %%
### TO RUN
myds.mod_data_aug(['add_bg'])
y_aug = np.repeat(classnames, dataset.naudio*myds.data_aug_factor) # Labels

"Compute the matrixed dataset, this takes some seconds, but you can then reload it by commenting this loop and decommenting the np.load below"
X_aug = np.zeros((myds.data_aug_factor*nclass*naudio, featveclen))
for s in range(myds.data_aug_factor):
    for idx in range(dataset.naudio):
        for class_idx, classname in enumerate(classnames):
            featvec = myds[classname, idx]  
            X_aug[s*nclass*naudio+class_idx*naudio+idx,:] = featvec 
np.save(fm_dir+"feature_matrix_2D_aug.npy", X_aug)

# X_aug = np.load(fm_dir+"feature_matrix_2D_aug.npy")

print('Shape of the feature matrix : {}'.format(X_aug.shape))
print('Number of labels : {}'.format(len(y_aug)))
# Out:
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\birds_31.wav
# (array([ 0.08333435, -0.10281609, -0.00869845, ...,  0.42896922,
#        -0.43535624, -0.08201717]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\helicopter_26.wav
# (array([ 0.05294416,  0.03176949,  0.30526679, ..., -0.00427901,
#         0.02524127,  0.02108992]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\birds_33.wav
# (array([ 0.02435691,  0.02488452,  0.01953229, ..., -0.03540035,
#        -0.02659298, -0.01729249]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\fire_34.wav
# (array([ 0.10094965,  0.06557333,  0.0438255 , ..., -0.00787932,
#        -0.00703147, -0.00339616]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\fire_13.wav
# (array([-0.03098734,  0.3101066 ,  0.06565049, ...,  0.51782402,
#        -0.04826314,  0.37816491]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_28.wav
# (array([ 0.03317385,  0.0496694 ,  0.07650784, ..., -0.15894692,
#        -0.33200658, -0.33214324]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\fire_1.wav
# (array([ 0.1196448 , -0.00702448,  0.05537256, ...,  0.48939897,
#         0.52883852,  0.53971437]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\fire_21.wav
# (array([-0.00175012, -0.00519883, -0.01563101, ..., -0.06605875,
#        -0.08675638, -0.03767047]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\fire_36.wav
# (array([-0.01621353, -0.00288143,  0.00935047, ..., -0.05369338,
#        -0.17959834, -0.31087237]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_33.wav
# (array([-0.24599658, -0.15800525, -0.35878534, ..., -0.08105027,
#         0.06473554, -0.03433282]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\helicopter_35.wav
# (array([ 0.03434707,  0.03518592, -0.02156982, ...,  0.08163909,
#         0.05193711,  0.0076074 ]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\helicopter_8.wav
# (array([ 0.23351003,  0.487995  ,  0.30445059, ..., -0.04093073,
#        -0.10896842, -0.20042916]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\helicopter_28.wav
# (array([0.0379755 , 0.03283628, 0.02979357, ..., 0.02811918, 0.02374984,
#        0.0345714 ]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\helicopter_20.wav
# (array([-0.03759895, -0.04168699, -0.0430934 , ..., -0.42845762,
#         0.12962263,  0.52589455]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\birds_1.wav
# (array([ 0.28917436,  0.2386168 ,  0.18523479, ...,  0.63875727,
#         0.45153829, -0.31962329]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\birds_9.wav
# (array([ 0.00862437,  0.01725849,  0.02244546, ..., -0.03048998,
#         0.02576169, -0.13456242]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\helicopter_17.wav
# (array([ 0.17952083,  0.181552  ,  0.23886364, ..., -0.23899712,
#        -0.27714561, -0.18876711]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_24.wav
# (array([-0.00102844, -0.02348636,  0.05257565, ..., -0.04807508,
#        -0.05605879, -0.04089591]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_31.wav
# (array([ 0.0247763 ,  0.03848852,  0.02397544, ..., -0.18107878,
#        -0.18880623, -0.21080312]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_18.wav
# (array([ 0.07637074,  0.04571476, -0.05101625, ..., -0.42211306,
#        -0.51336094, -0.45024977]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\fire_20.wav
# (array([ 0.00207665, -0.0013096 , -0.00601362, ..., -0.0081205 ,
#        -0.02483808,  0.048543  ]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\helicopter_28.wav
# (array([0.06617685, 0.05960853, 0.07017166, ..., 0.03655393, 0.03463757,
#        0.03992007]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_1.wav
# (array([-0.08286157, -0.083623  , -0.03718039, ...,  0.24524528,
#         0.20129745,  0.11517409]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\birds_14.wav
# (array([ 0.41701104,  0.40229689,  0.50745477, ..., -0.06186551,
#        -0.0445009 , -0.01166535]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\fire_36.wav
# (array([-0.42782672, -0.41397323, -0.45209407, ...,  0.08341962,
#         0.14241648,  0.06254047]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\fire_8.wav
# (array([-0.01083224,  0.01190527,  0.00227601, ...,  0.07116635,
#        -0.01767295,  0.03098401]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\helicopter_24.wav
# (array([-0.18521023,  0.00265914, -0.05640071, ...,  0.04222288,
#         0.03260325,  0.05117328]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\birds_2.wav
# (array([-0.08028752, -0.04591613, -0.05231732, ...,  0.01066059,
#        -0.04169359, -0.10448592]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\helicopter_9.wav
# (array([-0.00427503, -0.01649838, -0.01588622, ..., -0.07207643,
#        -0.04139898, -0.01874079]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\birds_31.wav
# (array([ 0.13238472, -0.0472497 , -0.11569259, ..., -0.01778103,
#        -0.1757752 , -0.1931119 ]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\birds_8.wav
# (array([0.32950339, 0.30595705, 0.31556373, ..., 0.25122785, 0.19806941,
#        0.2952104 ]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_6.wav
# (array([ 0.06187724,  0.15439073, -0.01686895, ..., -0.00231511,
#        -0.00213754,  0.00704847]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\helicopter_3.wav
# (array([-0.01019338, -0.00905337, -0.01194716, ...,  0.02382616,
#         0.00984649, -0.01474817]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\birds_15.wav
# (array([ 0.04626056, -0.01682574, -0.11353793, ...,  0.30858664,
#         0.62824822,  0.70872099]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\fire_10.wav
# (array([ 0.17363814,  0.60242411,  0.63838308, ..., -0.26570122,
#        -0.24100765, -0.20545308]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\helicopter_35.wav
# (array([0.11386783, 0.11430987, 0.0965508 , ..., 0.14720407, 0.12625765,
#        0.11670162]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\birds_26.wav
# (array([ 0.03512987,  0.11306676,  0.46220582, ...,  0.03793854,
#         0.00155036, -0.16386069]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\helicopter_29.wav
# (array([ 0.56085831,  0.5409677 ,  0.60712443, ..., -0.09977438,
#        -0.13575219, -0.23160146]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\helicopter_7.wav
# (array([ 0.01584222,  0.0754815 ,  0.07291999, ..., -0.02194925,
#        -0.05590427, -0.10161609]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\helicopter_4.wav
# (array([0.1023031 , 0.30627741, 0.31477017, ..., 0.12453386, 0.13112143,
#        0.14586002]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\helicopter_4.wav
# (array([ 0.00957338, -0.36445592,  0.06259907, ...,  0.0345128 ,
#         0.13227805,  0.13802876]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_24.wav
# (array([-0.25400326, -0.57252579, -0.41763702, ..., -0.11794598,
#        -0.08088043, -0.09957171]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\helicopter_4.wav
# (array([0.08715161, 0.11737262, 0.12025927, ..., 0.25935284, 0.34814216,
#        0.37389327]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\handsaw_20.wav
# (array([ 0.02394704,  0.00674086,  0.04439299, ..., -0.0752543 ,
#        -0.04677788, -0.05755004]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_37.wav
# (array([-0.01266043, -0.0309613 , -0.04832231, ..., -0.06901072,
#        -0.1044206 , -0.13224553]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\fire_1.wav
# (array([-0.05525181,  0.24997452, -0.11576007, ..., -0.19341011,
#        -0.05352641, -0.10748832]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\fire_8.wav
# (array([ 0.12298395,  0.14485787,  0.09659584, ..., -0.04286354,
#         0.00890961,  0.30202774]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\helicopter_8.wav
# (array([-0.00336729, -0.00741222, -0.00943849, ...,  0.03617018,
#         0.00621639, -0.01759993]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\fire_12.wav
# (array([-0.16107199, -0.1821314 , -0.19968647, ..., -0.02635039,
#        -0.03648566,  0.02376305]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\handsaw_28.wav
# (array([0.14953828, 0.11061503, 0.05340481, ..., 0.36600612, 0.31999095,
#        0.28663907]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_32.wav
# (array([ 0.08595942, -0.00868692, -0.15243471, ...,  0.05194079,
#        -0.14692144,  0.12736318]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\fire_34.wav
# (array([-0.01515333,  0.02420056, -0.02718682, ..., -0.06872884,
#        -0.06595302, -0.06074553]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\birds_7.wav
# (array([-0.3798002 , -0.38295782, -0.3699448 , ..., -0.46076254,
#        -0.51612703, -0.5274955 ]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_5.wav
# (array([0.01950131, 0.08470409, 0.10125034, ..., 0.07098689, 0.0624613 ,
#        0.06609844]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\fire_38.wav
# (array([-0.22467613, -0.26603799, -0.28487157, ..., -0.510807  ,
#        -0.45415173, -0.38865689]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_17.wav
# (array([ 0.00231889,  0.00376822, -0.0101466 , ..., -0.67359397,
#        -0.59041493, -0.52157083]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\handsaw_29.wav
# (array([ 0.12634269,  0.17836354,  0.04035319, ..., -0.02574373,
#        -0.01236933, -0.01805409]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_1.wav
# (array([-0.00655795, -0.01009308, -0.01285888, ..., -0.00654086,
#        -0.01116873, -0.02041318]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\handsaw_13.wav
# (array([-0.11509078,  0.27340234,  0.02243212, ...,  0.56353254,
#        -0.10466677, -0.03155488]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\fire_12.wav
# (array([-0.01075557, -0.01388725, -0.00929696, ..., -0.0902682 ,
#        -0.08599961, -0.08591983]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\handsaw_8.wav
# (array([-0.13888717, -0.01124306,  0.01538198, ...,  0.15292048,
#         0.14043503,  0.06824966]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\handsaw_3.wav
# (array([ 0.0113099 , -0.08277269,  0.06284499, ..., -0.24090388,
#        -0.31900535, -0.05178037]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\handsaw_37.wav
# (array([-0.0797235 , -0.0154715 , -0.06664197, ...,  0.1891004 ,
#         0.09974356,  0.06883435]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\handsaw_10.wav
# (array([-0.06375937, -0.06305474, -0.03686893, ...,  0.01848873,
#        -0.32069652, -0.29465811]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\fire_31.wav
# (array([-0.31805749, -0.15257535, -0.2215187 , ..., -0.14119082,
#        -0.0801982 , -0.07016506]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\birds_16.wav
# (array([0.23744161, 0.28497275, 0.25678029, ..., 0.18519844, 0.15016942,
#        0.16790946]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_34.wav
# (array([-0.00465097, -0.0357647 ,  0.00255274, ..., -0.21270101,
#        -0.21026591, -0.54273108]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\birds_14.wav
# (array([-0.05173789, -0.04643593, -0.06879233, ...,  0.06672247,
#         0.07939567,  0.05054755]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\birds_34.wav
# (array([-0.0445004 ,  0.11770458,  0.01555701, ...,  0.06153402,
#        -0.04510915, -0.00619694]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\handsaw_8.wav
# (array([0.20260052, 0.31530734, 0.39402332, ..., 0.21130595, 0.24194578,
#        0.2758341 ]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\helicopter_0.wav
# (array([ 0.54792435,  0.35853932,  0.06390392, ..., -0.2408311 ,
#        -0.18100718, -0.12739482]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\handsaw_8.wav
# (array([ 0.17805439, -0.14826623,  0.17833431, ...,  0.35473051,
#         0.01758721,  0.04614841]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\handsaw_27.wav
# (array([ 0.1515293 ,  0.132235  , -0.05902038, ..., -0.19156215,
#        -0.24733009, -0.11571167]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\birds_14.wav
# (array([-0.13992122, -0.16369644,  0.07486111, ...,  0.10947176,
#        -0.00025719,  0.09390631]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\birds_0.wav
# (array([-0.38475316, -0.36417334, -0.18666749, ..., -0.57668689,
#        -0.30661921, -0.02235928]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\handsaw_13.wav
# (array([ 0.01983703, -0.02904149,  0.00441156, ..., -0.02696209,
#         0.0912983 , -0.0825657 ]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\handsaw_23.wav
# (array([ 0.01121761, -0.01289102,  0.00536643, ..., -0.05039525,
#         0.0435686 ,  0.36218824]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_36.wav
# (array([ 0.04341994,  0.0616388 ,  0.06073144, ..., -0.17125557,
#        -0.20370837, -0.29730837]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\handsaw_19.wav
# (array([0.08108488, 0.13800121, 0.21924734, ..., 0.18432355, 0.33341007,
#        0.31331   ]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\birds_0.wav
# (array([ 2.31795015e-01,  3.04233399e-02, -2.31429803e-02, ...,
#        -4.85800635e-02, -1.85511152e-04,  8.98230200e-02]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_31.wav
# (array([ 0.31190817, -0.31603648,  0.2185845 , ..., -0.25711842,
#        -0.14103993, -0.01556715]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\helicopter_21.wav
# (array([-0.02234682,  0.06727691, -0.0386219 , ..., -0.02386726,
#        -0.02845384, -0.0255966 ]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\birds_4.wav
# (array([-0.05643843,  0.03974437,  0.13214135, ...,  0.17378006,
#         0.0857452 ,  0.09959693]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\helicopter_8.wav
# (array([ 0.00230132,  0.01408774,  0.03065785, ..., -0.05980396,
#        -0.1388324 , -0.08662352]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\handsaw_4.wav
# (array([-0.03029477, -0.03969494, -0.03815733, ...,  0.15336295,
#         0.12058185,  0.01593191]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\helicopter_32.wav
# (array([-0.09151767, -0.0765502 , -0.11207248, ...,  0.21483051,
#         0.16878429,  0.11355592]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\handsaw_33.wav
# (array([-0.03144576, -0.0180539 ,  0.05007948, ..., -0.10169375,
#        -0.04018448, -0.09406976]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\handsaw_31.wav
# (array([-0.28659485, -0.11945048, -0.25700016, ..., -0.36570864,
#        -0.36130716, -0.35751568]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\helicopter_15.wav
# (array([-0.20567161, -0.05729418,  0.14860945, ...,  0.00033191,
#         0.02723856, -0.02951457]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\helicopter_12.wav
# (array([0.01310411, 0.08977573, 0.14266755, ..., 0.2218026 , 0.23656447,
#        0.20926874]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_12.wav
# (array([-0.01255565, -0.02177814, -0.03541743, ..., -0.00884498,
#        -0.00636589, -0.00261648]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_18.wav
# (array([ 0.40991865,  0.16075557,  0.22268874, ..., -0.0154217 ,
#         0.09140082, -0.17736639]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_38.wav
# (array([-0.02629371, -0.06093214, -0.07420981, ...,  0.07795339,
#         0.1937509 ,  0.14727205]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\helicopter_3.wav
# (array([ 0.01105441,  0.03679075,  0.02898244, ..., -0.05449013,
#        -0.0013734 ,  0.03205814]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\birds_13.wav
# (array([-0.50620318, -0.50066082, -0.44296082, ..., -0.06817226,
#         0.00202091,  0.05904188]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\fire_0.wav
# (array([-0.02467851, -0.05950499, -0.049877  , ..., -0.16589334,
#        -0.12475967, -0.02603002]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_15.wav
# (array([-0.11470516,  0.09922848,  0.29232635, ...,  0.08965132,
#         0.1058147 ,  0.08732145]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\birds_21.wav
# (array([-0.291886  , -0.404457  , -0.33830667, ...,  0.36820128,
#         0.38037313,  0.3417783 ]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\handsaw_7.wav
# (array([-0.00339519, -0.03216464,  0.00577698, ..., -0.0240865 ,
#        -0.05408915,  0.04052481]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\fire_2.wav
# (array([ 0.0939577 , -0.02904688, -0.02883522, ...,  0.16028152,
#         0.18515184,  0.05849721]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\handsaw_25.wav
# (array([-0.362863  , -0.38922801, -0.41937266, ..., -0.19892558,
#        -0.60631808, -0.36988811]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\fire_10.wav
# (array([ 0.01353971, -0.00612812,  0.01557488, ...,  0.01954595,
#        -0.02590436, -0.08735627]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\birds_19.wav
# (array([-0.49507208, -0.50655647, -0.51247301, ..., -0.28106006,
#        -0.24045592, -0.23941814]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\handsaw_17.wav
# (array([-0.12231564,  0.22355674,  0.17052039, ...,  0.1240329 ,
#         0.09480707,  0.07354342]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_17.wav
# (array([0.6236801 , 0.64033938, 0.63554145, ..., 0.44309537, 0.40758216,
#        0.39313172]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\fire_27.wav
# (array([ 0.05558967, -0.0130793 ,  0.08810855, ..., -0.07897716,
#        -0.08666347, -0.08484347]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_26.wav
# (array([-0.08287154, -0.06260274, -0.03172936, ..., -0.08169363,
#         0.07152903,  0.19765277]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\helicopter_22.wav
# (array([ 0.24510666,  0.23889762,  0.23979502, ..., -0.02465405,
#        -0.03229192, -0.03318767]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_0.wav
# (array([0.05831897, 0.02327368, 0.01584523, ..., 0.12993235, 0.10252361,
#        0.127082  ]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_18.wav
# (array([-0.11556294, -0.09159571, -0.06757612, ...,  0.09485043,
#         0.08986803,  0.07959743]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_9.wav
# (array([ 0.30588691, -0.24966463,  0.10021471, ..., -0.03926145,
#        -0.07272215, -0.09366473]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\fire_9.wav
# (array([ 0.28434729,  0.32322484, -0.00067659, ...,  0.18102599,
#         0.17542479,  0.30719299]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\birds_1.wav
# (array([ 0.12971286,  0.10891835,  0.08459666, ..., -0.2604901 ,
#        -0.2705438 , -0.29155698]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\birds_0.wav
# (array([-0.00594004, -0.05013768, -0.07053888, ..., -0.05556115,
#         0.23022279,  0.2313286 ]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\handsaw_32.wav
# (array([0.0498581 , 0.09999338, 0.13921017, ..., 0.10552747, 0.11708177,
#        0.11294612]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\handsaw_26.wav
# (array([-0.21942163, -0.33803479, -0.5804019 , ...,  0.03033427,
#         0.26128048,  0.3619087 ]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_25.wav
# (array([-0.59217913, -0.25106558, -0.16613746, ..., -0.12111664,
#        -0.09916912, -0.11972356]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\helicopter_19.wav
# (array([-0.12957543, -0.11179528, -0.12562582, ..., -0.19012508,
#        -0.15789579, -0.17964997]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\handsaw_9.wav
# (array([-0.38808018, -0.394934  , -0.31988066, ...,  0.03919899,
#         0.03743806,  0.01506614]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_30.wav
# (array([ 0.17728337,  0.18018972,  0.17265795, ..., -0.05393587,
#        -0.06090733, -0.05664197]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\helicopter_32.wav
# (array([ 0.1427073 , -0.1528201 ,  0.06048362, ...,  0.15840638,
#         0.15507453,  0.17975427]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\helicopter_28.wav
# (array([-0.16914127,  0.11132071, -0.07848227, ...,  0.03305316,
#         0.02101332,  0.01576954]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_21.wav
# (array([ 0.202902  ,  0.21564733,  0.21305418, ..., -0.18966821,
#        -0.59103878, -0.70393184]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\birds_22.wav
# (array([-0.0687633 ,  0.00651617,  0.08116824, ..., -0.03550124,
#        -0.03063482, -0.07797222]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_38.wav
# (array([0.3102256 , 0.26756665, 0.25721703, ..., 0.04590234, 0.08976945,
#        0.08189389]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\handsaw_7.wav
# (array([-0.15925287, -0.23648957,  0.08021711, ..., -0.08496877,
#        -0.23055394, -0.25868052]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_17.wav
# (array([-0.02485749,  0.17598018,  0.03217101, ..., -0.00264471,
#        -0.28417283, -0.11629044]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_16.wav
# (array([-0.17203879, -0.19079301, -0.13184147, ..., -0.01771857,
#        -0.01536802, -0.01462949]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_28.wav
# (array([ 0.00844764, -0.00496412,  0.02052363, ..., -0.61639987,
#        -0.4456148 , -0.30922144]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\birds_0.wav
# (array([ 0.00094746,  0.01637638, -0.00749402, ...,  0.18254336,
#         0.15243964,  0.21666697]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\handsaw_31.wav
# (array([ 0.16399554,  0.15989976,  0.05700822, ...,  0.17090312,
#         0.10376062, -0.28430637]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\fire_37.wav
# (array([0.29751181, 0.52794658, 0.67222608, ..., 0.2324442 , 0.14486467,
#        0.13744306]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_26.wav
# (array([-0.93756657, -0.93116187, -0.91741919, ..., -0.05443637,
#         0.01609522, -0.00480506]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\birds_9.wav
# (array([ 0.22186486,  0.11741207, -0.06626355, ...,  0.06472951,
#         0.05328834,  0.12365207]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\birds_1.wav
# (array([-0.19483524, -0.20065056, -0.20367216, ..., -0.35155071,
#        -0.36041464, -0.40052257]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_30.wav
# (array([ 0.2085497 ,  0.3047614 ,  0.21765998, ..., -0.17168494,
#        -0.19098561, -0.2460045 ]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_23.wav
# (array([ 0.1758933 ,  0.06892274,  0.26922386, ..., -0.05440566,
#         0.00978126,  0.02796764]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\helicopter_19.wav
# (array([-0.10174029, -0.08731793, -0.08612466, ...,  0.16881531,
#         0.17634924,  0.17336758]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\birds_7.wav
# (array([-0.32677185, -0.44180437,  0.11812849, ..., -0.17902894,
#        -0.21302022, -0.08240905]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\handsaw_6.wav
# (array([-0.32027161, -0.31360551, -0.30981242, ...,  0.40054587,
#         0.36127628,  0.32536884]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\birds_17.wav
# (array([ 0.16070141,  0.22087094,  0.16482124, ..., -0.0918725 ,
#         0.29705977,  0.19532282]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_23.wav
# (array([0.14536617, 0.14487667, 0.14536615, ..., 0.12556986, 0.14234665,
#        0.32506704]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\handsaw_11.wav
# (array([-0.13159066, -0.10242562, -0.02970024, ...,  0.27126124,
#         0.28669762,  0.27794289]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\fire_11.wav
# (array([ 0.0944885 ,  0.08465342, -0.00489697, ..., -0.08923655,
#        -0.13410974, -0.07318387]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\birds_5.wav
# (array([ 0.22024355,  0.22314301,  0.27228999, ..., -0.27210588,
#        -0.26871753, -0.29790902]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_11.wav
# (array([-0.0425391 , -0.05228898, -0.03498769, ..., -0.08444084,
#         0.10635262, -0.11743326]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\handsaw_11.wav
# (array([-0.08447325, -0.0606767 , -0.02197232, ..., -0.17128048,
#        -0.10613881, -0.03727508]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\handsaw_2.wav
# (array([0.01226113, 0.01563305, 0.03052015, ..., 0.00936369, 0.02680925,
#        0.04481825]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\birds_9.wav
# (array([ 0.03059381,  0.04373054,  0.01868536, ...,  0.10971427,
#        -0.03343544, -0.02266327]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\fire_0.wav
# (array([ 0.81254831,  0.84914619,  0.87238988, ..., -0.40336011,
#        -0.40337377, -0.42627554]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\handsaw_1.wav
# (array([-0.04125109, -0.0473677 , -0.13348178, ...,  0.00623536,
#         0.02361579,  0.0918004 ]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\fire_20.wav
# (array([-0.46436254, -0.36784242, -0.15153802, ..., -0.07692497,
#        -0.15992052, -0.31352174]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\birds_36.wav
# (array([-0.24116252, -0.17086078, -0.01503849, ..., -0.00233002,
#         0.02178117,  0.07375451]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_3.wav
# (array([-0.07754319, -0.04646851, -0.02794665, ..., -0.16622674,
#        -0.33863811,  0.1783741 ]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\handsaw_39.wav
# (array([-0.27639755, -0.30443522, -0.33417725, ...,  0.0590113 ,
#         0.08014871,  0.11754163]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\birds_4.wav
# (array([-0.79167281,  0.63288098, -0.22149659, ...,  0.00461529,
#        -0.25556431, -0.02447728]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\birds_8.wav
# (array([ 0.17480565,  0.27271004,  0.08875035, ...,  0.64463017,
#        -0.31895396,  0.05768342]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_30.wav
# (array([ 0.00164097, -0.00698571,  0.01696189, ..., -0.59961309,
#        -0.65141146, -0.67095363]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\birds_31.wav
# (array([ 0.02448483,  0.0176266 ,  0.01154169, ...,  0.18990497,
#        -0.18186344, -0.25312142]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\helicopter_8.wav
# (array([0.35527758, 0.3381218 , 0.31156978, ..., 0.03255367, 0.05433597,
#        0.03839748]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\birds_21.wav
# (array([-0.30322354, -0.15547049,  0.04904693, ...,  0.02158168,
#         0.12565601, -0.02992033]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_6.wav
# (array([0.25202971, 0.30449825, 0.52140549, ..., 0.02599746, 0.08766913,
#        0.16051645]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\fire_34.wav
# (array([0.15066648, 0.14317311, 0.13351983, ..., 0.13157789, 0.14599393,
#        0.15804826]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\fire_6.wav
# (array([-0.07430653, -0.03582521, -0.05749096, ...,  0.24424494,
#         0.22534539, -0.07787291]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_37.wav
# (array([-0.04353227, -0.03981302, -0.0209034 , ..., -0.27320328,
#        -0.28730314, -0.29016731]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\handsaw_22.wav
# (array([-8.01734504e-05, -7.88442944e-03,  1.15191809e-01, ...,
#         9.66249979e-02,  5.77630647e-03,  7.70305366e-02]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\helicopter_37.wav
# (array([-0.24441227,  0.03943692,  0.11667282, ..., -0.09504158,
#        -0.0400343 , -0.02722025]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_3.wav
# (array([ 0.25734551,  0.22822949,  0.21892199, ..., -0.25485245,
#        -0.24734691, -0.25714665]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\helicopter_12.wav
# (array([0.28592252, 0.14668485, 0.06329545, ..., 0.24356696, 0.01794625,
#        0.20812294]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\birds_24.wav
# (array([-0.10754474,  0.03415628,  0.15436409, ..., -0.10452861,
#        -0.0604774 , -0.02478983]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\helicopter_19.wav
# (array([ 0.00195374, -0.01264874,  0.00095605, ..., -0.02602771,
#         0.03142334, -0.19664118]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\birds_23.wav
# (array([-0.04646609,  0.16472454,  0.1825683 , ..., -0.00342204,
#        -0.04159174,  0.02531999]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\fire_18.wav
# (array([ 0.18474982,  0.13063937,  0.1378568 , ..., -0.25281232,
#        -0.26457425, -0.31292436]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\helicopter_9.wav
# (array([-0.01796149, -0.03991452, -0.03969942, ...,  0.10847485,
#         0.0870042 ,  0.32314736]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\birds_17.wav
# (array([-0.19742472, -0.26216356, -0.32957688, ...,  0.11794196,
#         0.17294363,  0.18722631]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\handsaw_24.wav
# (array([ 0.22452195,  0.28507741,  0.09331728, ..., -0.25841367,
#        -0.05190562,  0.09662275]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\helicopter_13.wav
# (array([ 0.01334684, -0.12325786, -0.04975341, ...,  0.04795561,
#        -0.04799262, -0.0982386 ]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_8.wav
# (array([0.04964619, 0.06380005, 0.05629267, ..., 0.09388231, 0.10809544,
#        0.20672303]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\helicopter_12.wav
# (array([0.00767795, 0.01556356, 0.0085452 , ..., 0.06481365, 0.05517277,
#        0.01665114]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\handsaw_19.wav
# (array([-0.13604984, -0.08191725,  0.05155764, ...,  0.14874244,
#        -0.00753233, -0.07163279]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\handsaw_19.wav
# (array([ 0.64457378, -0.59325654,  0.85380299, ...,  0.042556  ,
#         0.0459271 ,  0.04780889]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\fire_38.wav
# (array([-0.17016895, -0.25108179, -0.33435704, ...,  0.00820782,
#         0.01111611,  0.01547865]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_4.wav
# (array([ 0.35309049,  0.28728614,  0.30629445, ...,  0.25302578,
#         0.0352096 , -0.01663143]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\fire_18.wav
# (array([-0.01286321, -0.01691572, -0.01368494, ..., -0.02398425,
#        -0.0271981 , -0.02941797]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\fire_9.wav
# (array([ 0.36832206,  0.38160375,  0.37876507, ..., -0.80718977,
#        -0.90192779, -1.        ]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\fire_23.wav
# (array([-0.2501147 , -0.16825663, -0.19903946, ..., -0.04454995,
#        -0.06871253, -0.10027379]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\handsaw_34.wav
# (array([-0.18048457, -0.23135331, -0.5204512 , ...,  0.70208638,
#         0.3670393 ,  0.36034096]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\birds_10.wav
# (array([ 0.13234116,  0.16023056,  0.09623658, ..., -0.05690305,
#         0.2443268 ,  0.43591326]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\helicopter_30.wav
# (array([ 0.00597926,  0.01127362,  0.0146206 , ..., -0.01964324,
#        -0.01601302, -0.00527635]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\helicopter_26.wav
# (array([0.19506228, 0.14028488, 0.1040987 , ..., 0.24779286, 0.12254986,
#        0.09709019]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\handsaw_5.wav
# (array([-0.03597074, -0.1587724 , -0.28629258, ..., -0.143733  ,
#        -0.21624942, -0.12633867]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\helicopter_16.wav
# (array([0.52612944, 0.30529355, 0.29476926, ..., 0.27209536, 0.24712663,
#        0.0657137 ]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\fire_4.wav
# (array([-0.0748015 , -0.10267868, -0.08279249, ...,  0.00532444,
#         0.00993384,  0.00952609]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\handsaw_16.wav
# (array([-1.29168134e-02,  8.64784124e-05, -8.64673190e-05, ...,
#        -7.24449140e-02, -1.11541881e-01, -1.16694763e-01]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\helicopter_12.wav
# (array([-0.12679202, -0.04758009,  0.06813677, ...,  0.1182477 ,
#         0.12298998,  0.12259266]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\birds_28.wav
# (array([-0.21964181, -0.25025011, -0.31656929, ..., -0.64742093,
#        -0.61735384, -0.48472741]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\handsaw_14.wav
# (array([0.03474556, 0.02615294, 0.02199371, ..., 0.42956106, 0.38008018,
#        0.42432541]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\birds_7.wav
# (array([-0.23619976, -0.23965109, -0.23803679, ..., -0.57145246,
#        -0.59577102, -0.60489665]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_28.wav
# (array([-0.05049409, -0.0867361 , -0.0756821 , ..., -0.43919438,
#        -0.37404242, -0.45184851]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\helicopter_19.wav
# (array([-0.00197653, -0.01010796, -0.02810713, ..., -0.04436735,
#        -0.04544228,  0.02433399]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\handsaw_11.wav
# (array([-0.00026206, -0.05605867,  0.01008735, ...,  0.0308473 ,
#         0.12091588,  0.09671103]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\birds_35.wav
# (array([-0.27640579, -0.37767067, -0.2459903 , ...,  0.10468339,
#         0.10085752,  0.11728676]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_13.wav
# (array([-0.01340665, -0.0158553 , -0.01597847, ..., -0.01102876,
#        -0.02083366, -0.02286511]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\handsaw_1.wav
# (array([-0.0269515 , -0.02031041, -0.09277571, ..., -0.06936988,
#         0.06159664,  0.35622686]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_9.wav
# (array([-0.07659036, -0.1585924 , -0.14439336, ..., -0.42796513,
#        -0.54648807, -0.4468157 ]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_7.wav
# (array([ 0.0334764 ,  0.01414397, -0.05401041, ..., -0.01930467,
#        -0.10461124,  0.01468125]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\fire_22.wav
# (array([-0.01283113, -0.08383188,  0.06248827, ...,  0.08146681,
#         0.10470236,  0.04891366]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\helicopter_35.wav
# (array([0.01647754, 0.04610186, 0.02564756, ..., 0.03607994, 0.03182859,
#        0.03156662]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\helicopter_27.wav
# (array([-0.1780331 , -0.10727603, -0.0394065 , ...,  0.02160902,
#        -0.0950557 , -0.07977689]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\birds_28.wav
# (array([-0.13796992, -0.06857108, -0.04239654, ..., -0.00803961,
#        -0.04688578,  0.04369212]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\fire_27.wav
# (array([ 0.05995795,  0.10303331,  0.08577867, ..., -0.42474207,
#        -0.47377247, -0.49514538]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\birds_30.wav
# (array([-0.27320888, -0.10854057, -0.19452915, ...,  0.02223866,
#         0.04998863, -0.07467992]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\handsaw_27.wav
# (array([ 0.05558758,  0.05778726, -0.03613136, ..., -0.06756408,
#        -0.08582874, -0.01953797]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_30.wav
# (array([ 0.06538083,  0.09267754,  0.06428283, ..., -0.00576216,
#        -0.12664027,  0.01432895]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\birds_33.wav
# (array([-0.19225216, -0.26843908, -0.13145273, ..., -0.64507736,
#        -0.58257722, -0.40304033]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\handsaw_26.wav
# (array([-0.02998069, -0.07688329, -0.08591854, ..., -0.24463115,
#         0.20873625,  0.05587817]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\helicopter_18.wav
# (array([-0.292034  , -0.27839965, -0.15730474, ...,  0.10077523,
#         0.13372966,  0.13890439]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_34.wav
# (array([-0.1062957 , -0.12853877, -0.12998357, ..., -0.0405516 ,
#        -0.02895894, -0.03185139]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\birds_15.wav
# (array([-0.00205537, -0.08962115, -0.24243443, ...,  0.02555437,
#         0.14710118,  0.19120944]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_23.wav
# (array([ 0.13542616,  0.05088494, -0.00852588, ...,  0.06954136,
#        -0.03857157, -0.084366  ]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\fire_9.wav
# (array([-0.01476811, -0.0064371 , -0.01605922, ...,  0.02352461,
#        -0.13161487,  0.09451387]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\handsaw_34.wav
# (array([ 0.01075726,  0.02373383, -0.00290343, ..., -0.08080216,
#        -0.08397819, -0.07744184]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_7.wav
# (array([-0.00149476, -0.00041153, -0.00558974, ..., -0.03002829,
#        -0.04206629, -0.04734553]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_24.wav
# (array([ 0.0237535 ,  0.04429015,  0.05104106, ..., -0.15113154,
#        -0.08043404, -0.0323519 ]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\fire_11.wav
# (array([0.10730734, 0.14875945, 0.0150308 , ..., 0.1909395 , 0.13917174,
#        0.12977239]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_31.wav
# (array([ 0.0297519 ,  0.11693925,  0.18091098, ..., -0.1982124 ,
#        -0.17513576, -0.0019699 ]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_4.wav
# (array([-0.08407138, -0.06186828, -0.13838131, ..., -0.1566054 ,
#        -0.10991669, -0.10999335]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\birds_9.wav
# (array([-0.00661928, -0.00516054,  0.01445292, ..., -0.06559495,
#        -0.06979137, -0.06459565]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\birds_25.wav
# (array([ 0.02229069, -0.01632228, -0.04089047, ..., -0.21991158,
#        -0.25715647, -0.27945771]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_28.wav
# ...
#         0.05229545,  0.26642674]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\fire_24.wav
# (array([-0.19019769, -0.12920838, -0.19113136, ..., -0.21895245,
#        -0.16064544, -0.12141974]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\birds_9.wav
# (array([ 0.17688135, -0.20771853,  0.35540329, ..., -0.19389635,
#        -0.13507093, -0.21459521]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_11.wav
# (array([ 0.0082969 , -0.01214378, -0.02700355, ..., -0.01554492,
#        -0.01062572, -0.20089051]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\fire_30.wav
# (array([-0.04465104, -0.05076876, -0.04212921, ..., -0.068998  ,
#        -0.05968146, -0.0783996 ]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_36.wav
# (array([ 0.05769939,  0.19387945,  0.18354966, ..., -0.14346558,
#        -0.08655941, -0.15857337]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\handsaw_1.wav
# (array([0.04827912, 0.0672575 , 0.03629856, ..., 0.01210018, 0.0667942 ,
#        0.12457207]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\fire_25.wav
# (array([-0.25591563, -0.25982605, -0.20059128, ...,  0.39242849,
#         0.37316887,  0.35096373]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\handsaw_13.wav
# (array([-0.25411279, -0.08027167, -0.13863863, ..., -0.26749261,
#        -0.16292072, -0.16931331]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\fire_7.wav
# (array([ 0.09065587,  0.05431756,  0.06984047, ..., -0.25271012,
#        -0.1808484 , -0.23409691]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\handsaw_4.wav
# (array([0.01702238, 0.01561523, 0.01514231, ..., 0.0044575 , 0.00409155,
#        0.00509012]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\helicopter_30.wav
# (array([-0.53625057, -0.54043068, -0.55489899, ...,  0.21239467,
#         0.19259798,  0.17518052]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_0.wav
# (array([-0.05555828, -0.08428316, -0.09448885, ...,  0.40849651,
#         0.42198594,  0.43091274]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\birds_12.wav
# (array([-0.41657253, -0.03917612,  0.41669856, ...,  0.05418021,
#         0.07704232, -0.03646888]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\birds_6.wav
# (array([ 0.34423587,  0.35236058,  0.36947997, ..., -0.14362038,
#        -0.1503209 , -0.1393729 ]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\helicopter_27.wav
# (array([-0.10675696,  0.15458796,  0.15877895, ...,  0.71676038,
#         0.40251636,  0.38346569]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\helicopter_13.wav
# (array([-0.03739785, -0.00441088,  0.01810243, ..., -0.03406265,
#        -0.05221475, -0.07920781]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\handsaw_2.wav
# (array([-0.03716016,  0.00716075,  0.04492089, ...,  0.17737506,
#         0.09976938,  0.11158327]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\birds_36.wav
# (array([-0.25049466, -0.19045283, -0.02859108, ..., -0.02504862,
#         0.02470613,  0.05799984]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\helicopter_27.wav
# (array([-0.13474809, -0.18174025, -0.16115832, ..., -0.0392606 ,
#        -0.04671829, -0.05136729]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\fire_13.wav
# (array([ 0.01928534,  0.01863525, -0.00034392, ...,  0.07172494,
#         0.01636343,  0.08770321]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\fire_30.wav
# (array([0.17290608, 0.12089176, 0.07793126, ..., 0.19567835, 0.20972963,
#        0.19556634]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\handsaw_28.wav
# (array([ 0.04752469,  0.06129571,  0.08065648, ...,  0.02337324,
#        -0.00045479, -0.00588694]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\helicopter_14.wav
# (array([0.12939687, 0.1694346 , 0.14976629, ..., 0.19648171, 0.50939134,
#        0.2613136 ]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_20.wav
# (array([-0.09576437, -0.12374908, -0.11396339, ..., -0.23506506,
#        -0.20959192, -0.18383476]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\handsaw_28.wav
# (array([ 0.24329678, -0.12537051, -0.04588265, ...,  0.13421098,
#         0.05347353,  0.05062064]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\handsaw_35.wav
# (array([0.41208544, 0.42614179, 0.46354231, ..., 0.13235635, 0.11924036,
#        0.11213307]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_30.wav
# (array([ 0.12806631,  0.20626659,  0.16127469, ..., -0.14772332,
#        -0.16991296, -0.20876695]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\helicopter_27.wav
# (array([ 0.04737313, -0.21918049, -0.39112215, ...,  0.00279758,
#        -0.12747032, -0.07126261]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\handsaw_11.wav
# (array([-0.11397155, -0.07182803, -0.02387123, ...,  0.26396172,
#         0.31032595,  0.26868257]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\handsaw_27.wav
# (array([ 0.20536368,  0.45489665,  0.38694016, ..., -0.15038295,
#         0.35378609,  0.40700376]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_31.wav
# (array([0.25405804, 0.30409647, 0.33441013, ..., 0.61238903, 0.59105766,
#        0.56064371]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_29.wav
# (array([ 0.08880721, -0.02695893, -0.03957804, ..., -0.16790187,
#         0.04072736, -0.26563636]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\fire_33.wav
# (array([ 0.08083928,  0.00964281,  0.0865    , ..., -0.0197142 ,
#        -0.01760537, -0.0195537 ]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\handsaw_7.wav
# (array([ 0.03678765,  0.030901  , -0.00683171, ..., -0.25958592,
#        -0.31657911, -0.33062562]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\fire_34.wav
# (array([-0.25692131, -0.12638361, -0.29181333, ..., -0.01594322,
#        -0.00432675,  0.06790981]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\helicopter_5.wav
# (array([-0.05493504, -0.09234643, -0.09663159, ...,  0.38131596,
#         0.35796362,  0.31552389]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_31.wav
# (array([ 0.05574254,  0.05880626,  0.151511  , ..., -0.05555321,
#        -0.03956958, -0.05141988]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\fire_9.wav
# (array([ 0.38815458,  0.06157579,  0.40934226, ...,  0.13091669,
#        -0.18257909, -0.14801169]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\birds_24.wav
# (array([-0.05033382,  0.0235227 ,  0.04459858, ..., -0.157744  ,
#        -0.13241118, -0.11901945]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_15.wav
# (array([-0.08421634, -0.04033753, -0.12851022, ...,  0.12585156,
#         0.07426555,  0.03480489]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\handsaw_35.wav
# (array([ 0.19283637,  0.16406624,  0.13990814, ..., -0.14839063,
#        -0.12857286, -0.05456371]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_27.wav
# (array([-0.18102187, -0.0484202 , -0.10024245, ..., -0.13245692,
#        -0.14252205, -0.13072679]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_18.wav
# (array([ 0.29357714,  0.1290568 ,  0.12501536, ..., -0.27601033,
#        -0.00491953,  0.29232487]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\helicopter_10.wav
# (array([-0.18140229, -0.1339033 , -0.08093961, ...,  0.01638738,
#         0.01734638,  0.06025757]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\birds_30.wav
# (array([-0.04970356, -0.03019397, -0.00291183, ...,  0.12569193,
#         0.17172155, -0.33830281]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\handsaw_0.wav
# (array([0.26304337, 0.25040163, 0.26636128, ..., 0.02656071, 0.11628703,
#        0.05207471]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_3.wav
# (array([-0.01387788, -0.02413699, -0.02113449, ..., -0.03484643,
#         0.05741108,  0.08253639]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\helicopter_6.wav
# (array([ 0.11182721,  0.08631583,  0.07630557, ...,  0.21575559,
#         0.14065282, -0.13534532]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\helicopter_2.wav
# (array([-0.06202102, -0.12091106, -0.091689  , ...,  0.02155539,
#         0.11386473,  0.14252273]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\helicopter_6.wav
# (array([-0.03531074, -0.04825122, -0.04539761, ...,  0.74643132,
#         0.3283337 ,  0.39375932]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\birds_27.wav
# (array([-0.02497791, -0.04597216,  0.01693936, ...,  0.04821448,
#         0.00710811,  0.00234166]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\fire_15.wav
# (array([-0.18764027, -0.14182078, -0.19000203, ...,  0.03566987,
#        -0.0079724 , -0.07210294]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\helicopter_13.wav
# (array([0.1831388 , 0.06124741, 0.02984095, ..., 0.07283656, 0.00809907,
#        0.07645879]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\helicopter_17.wav
# (array([-0.21675196, -0.23726351, -0.24872085, ...,  0.2160358 ,
#         0.21953529,  0.21688456]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_39.wav
# (array([-0.15667029,  0.0226399 , -0.19837998, ..., -0.01517413,
#        -0.00609959, -0.01274886]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\helicopter_0.wav
# (array([0.12208348, 0.17187278, 0.22401197, ..., 0.29120398, 0.49507159,
#        0.53384403]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_26.wav
# (array([ 0.18765   ,  0.16841838,  0.16121552, ..., -0.22293865,
#        -0.19619287, -0.26503908]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_10.wav
# (array([0.5349234 , 0.67017933, 0.77891631, ..., 0.0551886 , 0.03444197,
#        0.02699699]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\birds_3.wav
# (array([ 0.09773818,  0.05175917,  0.08188109, ..., -0.37357182,
#        -0.3295079 , -0.30855406]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\fire_31.wav
# (array([-0.14635244, -0.00674519,  0.13029124, ..., -0.01421296,
#        -0.01250661, -0.02368745]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\fire_23.wav
# (array([-0.09987886, -0.06355064, -0.04907296, ...,  0.13118162,
#         0.17281695,  0.19179992]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_24.wav
# (array([-0.11010823, -0.00747227,  0.00354699, ..., -0.14454826,
#        -0.2316257 , -0.14868245]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\fire_7.wav
# (array([0.21808119, 0.19803568, 0.11986742, ..., 0.69850165, 0.70710307,
#        0.55775059]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_8.wav
# (array([0.21336427, 0.29963021, 0.26431266, ..., 0.31045382, 0.43810047,
#        0.46322682]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\helicopter_14.wav
# (array([ 0.1288803 ,  0.17258541,  0.1517509 , ..., -0.01497193,
#        -0.04179641,  0.01520145]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\birds_39.wav
# (array([0.29884456, 0.23995708, 0.14700505, ..., 0.17988813, 0.1995756 ,
#        0.23661801]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\chainsaw_7.wav
# (array([0.15796778, 0.29565078, 0.26384251, ..., 0.39374942, 0.16992221,
#        0.01864532]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\handsaw_31.wav
# (array([-0.47778581, -0.37148511, -0.42046791, ..., -0.01195129,
#        -0.03674732,  0.03915851]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\birds_26.wav
# (array([-0.00793636, -0.00842221, -0.00656022, ...,  0.01094986,
#         0.02185396,  0.03848745]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\fire_3.wav
# (array([ 0.04195439,  0.04259725,  0.05076625, ..., -0.03176083,
#         0.01652942,  0.2911251 ]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\fire_17.wav
# (array([-0.02962445, -0.05572376,  0.07659081, ...,  0.09173906,
#         0.05443861,  0.03459915]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\fire_9.wav
# (array([0.02208658, 0.1053029 , 0.14772504, ..., 0.10966317, 0.25327766,
#        0.21137876]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\fire_19.wav
# (array([-0.02018803, -0.01150258, -0.00290853, ...,  0.18340206,
#         0.18183345,  0.2399804 ]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\handsaw_38.wav
# (array([-0.35223811, -0.32847059, -0.21637792, ...,  0.00964245,
#        -0.04642864, -0.08458422]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\birds_10.wav
# (array([0.12298738, 0.13622889, 0.1357887 , ..., 0.00061461, 0.16572949,
#        0.36942447]), 11025)
# D:\Master1\Q1\LELEC210x\LELEC210X\classification\src\classification\datasets\soundfiles\birds_30.wav
# (array([-0.01942957, -0.02943383, -0.01052521, ...,  0.22384899,
#         0.46705713,  0.3900053 ]), 11025)
# Shape of the feature matrix : (400, 400)
# Number of labels : 400

# %%
### TO RUN
K = 10 # Number of neighbours
model = KNeighborsClassifier(n_neighbors=K) 

accuracy_aug = np.zeros((n_splits,))
for k, idx in enumerate(kf.split(X_aug,y_aug)):
  (idx_train, idx_test) = idx
  model.fit(X_aug[idx_train], y_aug[idx_train])
  prediction_aug = model.predict(X_aug[idx_test])
  accuracy_aug[k] = accuracy(prediction_aug, y_aug[idx_test])

print('Mean accuracy with 5-Fold CV: {:.1f}%'.format(100*accuracy_aug.mean()))
print('Std deviation in accuracy with 5-Fold CV: {:.1f}%'.format(100*accuracy_aug.std()))
show_confusion_matrix(prediction_aug, y_aug[idx_test], classnames)
# Out:
# Mean accuracy with 5-Fold CV: 26.7%
# Std deviation in accuracy with 5-Fold CV: 1.7%

# %% [markdown]
# **Questions**:
# - Can you see an improvement of the classification result compared to the non augmented dataset? Try to interpret your answer by thinking about the distribution of points in a data space (as with the toy example), what does it imply to augment the data in terms of distribution of points in the data space?
# - With the ``add_bg`` augmentation technique, where are the additive background signals coming from? It is a good thing?
# - What transformations are most likely to be realistic in your application? What is the most efficient way to integrate these alterations in your classification task? ``Hint``: it does not require augmenting your data in Python.

# %%
### TO COMPLETE
# Answer the question above

# %% [markdown]
# <font size=5 color=#009999> 2.7. Getting it all together </font> <br>
#
# Now that some aspects to be considered during the model training and analysis have been presented, it remains to train and save a final model that will be used for further predictions.

# %%
### TO COMPLETE

# [1] Create dataset of feature vectors and split it.
# (optional) with data augmentation
myds = ...
# X_train, X_test, y_train, y_test = ...


# [2] (optional) Data normalization

# [3] (optional) dimensionality reduction.
...

# [4] Model training and selection.
model = ...
...

# [5] Save the trained model, eventually the pca.
filename = 'model.pickle'
pickle.dump(model, open(model_dir+filename, 'wb'))

# [6] Evaluate the model.

# %% [markdown]
# <font size=5 color=#009999> 2.8. Debriefing </font> <br>
# **Questions** :
#
# 1) from what we have done in this notebook, can you already identify some weaknesses in the feature vector computation and classification pipeline? You can make a list here below, and eventually write some short ideas for improvement. This will help you later :)
# 2) Do you remember what is the time duration of a feature vector? What happens if no sound is produced during the acquisition time of a feature vector?

# %%
### TO COMPLETE
# Answer the question above
